# %% [markdown]
# # TEDscraper Notebook

# %%
import pandas as pd
import re

import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import time
import random

import pickle

# %% [markdown]
# ## Soup Maker

# %%
class SoupMaker:
    """Make soup objects and put your machine to sleep."""
    

    def sleep_short(self):
        """Suspends execution time between 0 - .2 seconds."""
        return time.sleep(random.uniform(0, .2))

    def sleep_long(self):
        """Suspends execution time between .5 - 2 seconds."""
        return time.sleep(random.uniform(.5, 2))

    def make_soup(self, url):
        """Returns soup object from a URL."""
        # generate random user-agent
        user_agent = {'User-agent': UserAgent().random}
        # request page and make soup
        page = requests.get(url, headers=user_agent)
        soup = BeautifulSoup(page.content, 'lxml')
        return soup

# %% [markdown]
# ## CreateCSV

# %%
class CreateCSV(SoupMaker):
    """Create CSVs of TED topics and languages."""


    def create_topics_csv(self):
        """Creates CSV of all topics available from TED."""
        soup = self.make_soup('https://www.ted.com/topics')
        topic_list = []
        topic_tag = soup.find_all(class_='d:b', style='line-height:3;')
        for tag in topic_tag:
            topic = re.sub(r'\s+', '', tag.text)
            topic_list.append(topic)
        topics_series = pd.Series(topic_list, name='Topic')
        topics_series.to_csv('../data/topics.csv', index=False)

    def create_languages_csv(self):
        """Creates CSV of all language codes supported by TED."""
        lang_url = 'https://www.ted.com/participate/translate/our-languages'
        soup = self.make_soup(lang_url)
        lang_list = []
        lang_tags = soup.find_all('div', class_='h9')
        for tag in lang_tags:
            if tag.a == None:
                continue
            else:
                lang_code = re.search(r'(?<=\=)[\w-]+', tag.a['href']).group(0)
                lang_name = tag.text
                lang_list.append([lang_code] + [lang_name])
        lang_df = pd.DataFrame(data=lang_list, columns=['lang_code', 'language'])
        lang_df.to_csv('../data/languages.csv', index=False)
        
    def create_dataset(self, DataFrame):
        """Creates CSV from a DataFrame."""
        pass

# %% [markdown]
# ## Talk Features

# %%
class TalkFeatures(SoupMaker):
    """Class to get TED talk features."""


    def get_talk_id(self, soup):
        """Returns the talk_id provided by TED."""
        talk_id = re.search(r"(?<=\"current_talk\":)\"(\d+)\"", soup.text).group(1)
        return talk_id

    def get_title(self, soup):
        """Returns the title of the talk."""
        title_tag = soup.find(attrs={'name': 'title'}).attrs['content']
        tag_list = title_tag.split(':')
        title = ":".join(tag_list[1:]).lstrip()
        return title

    def get_speaker_1(self, soup):
        """Returns the first speaker in TED's speaker list."""
        speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", soup.text)[0]
        # convert to DataFrame
        speakers_df = pd.read_json(speaker_tag)
        full_name_raw = (speakers_df.loc[:, 'firstname'] + ' '
                     + speakers_df.loc[:, 'middleinitial'] + ' '
                     + speakers_df.loc[:, 'lastname'])
        full_name_clean = full_name_raw.str.replace('\s+', ' ')
        # transform series to a dict
        speaker_1 = full_name_clean.iloc[0]
        return speaker_1

    def get_all_speakers(self, soup):
        """Returns dict of all speakers per talk."""
        speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", soup.text)[0]
        # convert to DataFrame
        speakers_df = pd.read_json(speaker_tag)
        full_name_raw = (speakers_df.loc[:, 'firstname'] + ' '
                     + speakers_df.loc[:, 'middleinitial'] + ' '
                     + speakers_df.loc[:, 'lastname'])
        full_name_clean = full_name_raw.str.replace('\s+', ' ')
        # transform series to a dict
        speakers = full_name_clean.to_dict()
        return speakers

    def get_occupations(self, soup):
        """Returns list of the occupation(s) of the speaker(s) per talk."""
        occupations_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", soup.text)[0]
        # convert json to DataFrame
        occupations_series = pd.read_json(occupations_tag)['description']
        if occupations_series.all():
            # clean and create dict
            occupations = occupations_series.str.lower().str.split(', ')
            occupations = occupations.to_dict()
        else:
            occupations = None
        return occupations

    def get_about_speakers(self, soup):
        """Returns dict with each 'About the Speaker' blurb per talk."""
        speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", soup.text)[0]
        # convert to DataFrame
        about_series = pd.read_json(speaker_tag)['whotheyare']
        if about_series.all():
            # transform series to a dict
            about_speakers = about_series.to_dict()
        else:
            about_speakers = None
        return about_speakers

    def get_views(self, soup):
        """Returns viewed count per talk."""
        view_count = re.search(r"(?<=\"viewed_count\":)\d+", soup.text).group(0)
        return view_count

    def get_recorded_date(self, soup):
        """Returns date a talk was recorded."""
        recorded_at = re.search(r"(?<=\"recorded_at\":\")[\d-]+", soup.text).group(0)
        return recorded_at

    def get_published_date(self, soup):
        """Returns date a talk was published in TED.com."""
        published_raw = soup.find(attrs={'itemprop': 'uploadDate'}).attrs['content']
        published_date = re.search(r"[\d-]+", published_raw).group(0)
        return published_date

    def get_event(self, soup):
        """Returns name of the event in which the talk was given."""
        event = re.search(r"(?<=\"event\":)\"(.*?)\"", soup.text).group(1)
        return event
    
    def get_native_lang(self, soup):
        """Returns native language code for each talk as a string."""
        native_lang = re.search(r'(?<=nativeLanguage\":)\"(.*?)\"', soup.text).group(1)
        return native_lang
    
    def get_available_lang(self, soup):
        """Returns list of all available languages (lang codes) for a talk."""
        languages = re.findall(r'(?<=languageCode\":)\"(.*?)\"', soup.text)
        clean_lang = sorted(list(set(languages)))
        return clean_lang

    def get_comments_count(self, soup):
        """Return the count of comments per talk."""
        try:
            comments_count = re.search(r"(?<=\"count\":)(\d+)", soup.text).group(1)
        except AttributeError:
            comments_count = None
        return comments_count

    def get_duration(self, soup):
        """Returns duration of a talk in seconds."""
        duration =  re.search(r"(?<=\"duration\":)(\d+)", soup.text).group(1)
        return duration

    def get_topics(self, soup):
        """Returns list of tags (topics) per talk."""
        match_obj = re.search(r"\"tag\":\"(.*?)\"", soup.text)
        topics = match_obj.group(1).split(',')
        return topics

    def get_related_talks(self, soup):
        """Returns dict (keys: id & title) of related talks."""
        related_tag = re.search(r"(?<=\"related_talks\":).*?]", soup.text).group(0)
        related_sr = pd.read_json(related_tag)
        related_talks = dict(zip(related_sr['id'], related_sr['title']))
        return related_talks

    def get_talk_url(self, soup):
        """Returns url for each talk as a string."""
        talk_tag = soup.find(attrs={'property': 'og:url'}).attrs['content']
        talk_url = talk_tag.split('transcript')[0]
        return talk_url

    def get_description(self, soup):
        """Returns description of the talk."""
        desc_tag = soup.find(attrs={'property': 'og:description'}).attrs['content']
        talk_desc = desc_tag.split(': ', 1)[1]
        return talk_desc

    def get_transcript(self, soup):
        """Returns talk's transcript as a single string.""" 
        transcript = ''
        transcript_strings = []
        for div in soup.find_all('div', class_="Grid__cell flx-s:1 p-r:4"):
            for p in div.find_all('p'):
                # add every string in the transcript to a list
                transcript_strings.append(" ".join(p.text.split()))
            else:
                # after all strings have been added, create a single transcript string
                transcript = " ".join(transcript_strings)
        return transcript

# %% [markdown]
# ## URLs

# %%
class URLs(SoupMaker):
    """Get and process urls to scrape."""

    
    def topics_url_param(self):
        """Returns string of the url query from topics parameter."""
        topics_param = ''
        if self.topics != 'all':
            if isinstance(self.topics, list):
                for topic in self.topics:
                    topics_param += ('&topics[]=' + topic)
            else:
                raise ValueError("'topics' param needs to be a list")
        return topics_param

    def get_max_page(self):
        """Returns max pagination number from www.ted.com/talks."""
        page_num = [1]
        # make soup from ted.com/talks with specified language
        soup = self.make_soup(self.base_url + '&page=1&sort=newest')
        # iterate through each pagination element and get the max
        page_elem = soup.find_all('a', class_='pagination__item pagination__link')
        for element in page_elem:
            page_num.append(int(element.text))
        return max(page_num)
    
    def get_all_url_paths(self):
        """Returns list of all the talk url paths available in www.ted.com/talks"""
        url_path_list = []
        # construct url with lang code specified by the user
        talks_url = (self.base_url + '&page=')
        # set range from 1 to the max page in the pagination element
        page_range = range(1, self.get_max_page()+1)
        # iterate through each page and get the url for each talk
        for i in page_range:
            # try a second attempt if first attempt fails
            for attempt in range(2):
                try:
                    talks_page_url = talks_url + str(i) + '&sort=newest'
                    soup = self.make_soup(talks_page_url)
                    # delay between searches
                    self.sleep_short()
                    for div in soup.find_all('div', attrs={'class': 'media__image'}):
                        for a in div.find_all('a'):
                            url_path_list.append(a.get('href'))
                except:
                    # delay before continuing to second attempt
                    self.sleep_long()
                # break from attempts loop if no exceptions are raised
                else:
                    break
        return url_path_list

    def get_all_urls(self):
        """Returns list of complete urls for each talk's transcript page."""
        # '/talks/jen_gunter_why_can_t_we_talk_about_periods?language=fa'
        url_list = []
        for url in self.get_all_url_paths():
            url_list.append(('https://www.ted.com'
                             + url.replace(
                                 # to replace
                                 '?language=' + self.lang_code,
                                 # replace with
                                 '/transcript' + '?language=' + self.lang_code)
                            ))
        return url_list
    
    def clean_urls(self, urls):
        """Returns list of clean urls from urls the user inputs."""
        clean_urls = []
        for idx, url in enumerate(urls):
            if url.startswith('https://www.ted.com/talks'):
                parts = url.split('/')
                joined = '/'.join(parts[:5])
                clean = joined.split('?')
                lang = clean[0] + '/transcript?language=' + self.lang_code
                topic = lang + self.topics_url_param()
                clean_urls.append(lang)
            else:
                print(f'bad url @ {idx} >> {url}')
                continue
        return clean_urls
    
    def url_issues(self):
        """Returns DataFrame of urls with known issues."""
        issues_df = pd.read_csv('../data/urls_issues.csv')
        return issues_df
    
    def remove_urls_with_issues(self):
        """Remove urls with known issues to prevent unnecessary scraping."""
        urls = self.url_attribute()
        final_urls = []
        removed_urls = []
        removed_counter = 0
        issues_df = pd.read_csv('../data/urls_issues.csv')
        for url in urls:
            try:
                base_url = url.replace('transcript?language=' + self.lang_code, '')
                # is base url in the issues df?
                url_in_issues = (issues_df['url'] == base_url).any()
                # get the lang_codes of the base_url
                langs = issues_df.loc[issues_df['url'] == base_url, 'lang_code']
                # check if the url in issues_df
                if not url_in_issues:
                    final_urls.append(url)
                # if the url is in issues_df, check if it's for the same lang_code
                elif self.lang_code in langs.any():
                    removed_urls.append(url)
                    removed_counter += 1
                    continue
                else:
                    final_urls.append(url)
            except:
                removed_urls.append(url)
                removed_counter += 1
                continue
        if removed_urls:
            print(f"Removed the following {removed_counter} urls as they have "
                  "known issues:\n", removed_urls, end='\n\n')
        return final_urls

# %% [markdown]
# ## TEDscraper

# %%
class TEDscraper(TalkFeatures, URLs):
    """Gets urls and scrapes TED talk data in the specified language.

    Attributes:
        lang_code (str): Language code. Defaults to 'en'.
        language (str): Language name derived from lang_code.
        urls (list): URLs of talks. Defaults to 'all'.
        topics (list): Talk topics. Defaults to 'all'.
        exclude (bool): Exclude transcript. Defaults to False.
        ted_dict (dict): Dict to store ted talk features after scraping.
        dict_id (int): Index of nested dict in 'ted_dict'.
        failed_counter: Counts urls that failed to get scraped.
    """
    

    def __init__(self, lang_code='en', urls='all', topics='all',
                 force_fetch = False, exclude_transcript=False):
        self.lang_code = lang_code
        self.language = self.convert_lang_code()
        self.urls = urls
        self.topics = topics
        self.exclude = exclude_transcript
        self.ted_dict = {}
        self.dict_id = 0
        self.failed_counter = 0
        self.failed_urls = []
        self.force_fetch = force_fetch
        self.base_url = ('https://www.ted.com/talks'
                         + '?language=' + self.lang_code
                         + self.topics_url_param())
        
    def url_attribute(self):
        """Define urls attribute based on parameter 'urls'."""
        # define url attribute
        if self.urls == 'all':
            urls = self.get_all_urls()
        else:
            if isinstance(self.urls, list):
                urls = self.clean_urls(self.urls)
            else:
                raise ValueError("'urls' param needs to be a list")
        return urls

    def convert_lang_code(self):
        """Reads languages.csv and returns language.
        Parameters:
            lang_code (str): Language code
        """
        df = pd.read_csv('../data/languages.csv')
        lang_series = df.loc[(df['lang_code'] == self.lang_code), 'language']
        language = lang_series.values[0]
        return language
    
    def scrape_all_features(self, soup):
        """Scrapes all features to a nested dict."""
        # create nested dict
        self.ted_dict[self.dict_id] = {}
        nested_dict = self.ted_dict[self.dict_id]
        # add the features to the nested dict
        nested_dict['talk_id'] = self.get_talk_id(soup)
        nested_dict['title'] = self.get_title(soup)
        nested_dict['speaker_1'] = self.get_speaker_1(soup)
        nested_dict['all_speakers'] = self.get_all_speakers(soup)
        nested_dict['occupations'] = self.get_occupations(soup)
        nested_dict['about_speakers'] = self.get_about_speakers(soup)
        nested_dict['views'] = self.get_views(soup)
        nested_dict['recorded_date'] = self.get_recorded_date(soup)
        nested_dict['published_date'] = self.get_published_date(soup)
        nested_dict['event'] = self.get_event(soup)
        nested_dict['native_lang'] = self.get_native_lang(soup)
        nested_dict['available_lang'] = self.get_available_lang(soup)
        nested_dict['comments'] = self.get_comments_count(soup)
        nested_dict['duration'] = self.get_duration(soup)
        nested_dict['topics'] = self.get_topics(soup)
        nested_dict['related_talks'] = self.get_related_talks(soup)
        nested_dict['url'] = self.get_talk_url(soup)
        nested_dict['description'] = self.get_description(soup)
        # add transcript if param is set to False (default)
        if not self.exclude:
            nested_dict['transcript'] = self.get_transcript(soup)
        return nested_dict

    def get_data(self):
        """Returns nested dictionary of features from each talk's transcript page."""
        print("Fetching urls...\n")
        # define url attribute
        if self.force_fetch:
            urls = self.url_attribute()
        else:
            urls = self.remove_urls_with_issues()
        print(f"Scraping {len(urls)} TED talks in '{self.language}'...")
        print(f"Estimated time to complete is {round((.9*len(urls)/60), 1)} minutes\n")
        # iterate through each ted talk transcript url
        for url in urls:
            # make soup
            soup = self.make_soup(url)
            # taste soup
            taster = soup.title.text
            bad_soup = re.search(r'404: Not Found', taster)
            if bad_soup:
                print(f"[BAD_SOUP] {self.lang_code} {url}")
                self.failed_urls.append(url)
                self.failed_counter += 1
                continue
            # delay between searches
            self.sleep_short()
            # try up to three attempts to scrape data
            for attempt in range(1, 3+1):
                try:
                    # create nested dict
                    self.ted_dict[self.dict_id] = {}
                    # scrape features and add to a nested dict
                    self.scrape_all_features(soup)
                    # indicate successful scrape
                    print(f"[OK] {self.dict_id} {url}")
                    # add 1 to create a new nested dict
                    self.dict_id += 1
                except Exception as e:
                    # if the last attempt fails, update the failed counter
                    # and print the exception & talk url
                    if attempt == 3:
                        self.failed_counter += 1
                        self.failed_urls.append(url)
                        print(f"[EXCEPTION] {e} {url}")
                        continue
                    # delay before another attempt
                    self.sleep_long()
                # break if no exceptions are raised
                else:
                    break
        print(f"""\nTed.com scraping results:
            \n\t• Successful: {self.dict_id}
            \n\t• Failed: {self.failed_counter}\n""")
        if self.failed_counter:
            print(f"Failed to scrape:\n{self.failed_urls}\n")
        return self.ted_dict
    
    def to_dataframe(self, ted_dict):
        """Creates DataFrame object from dict."""
        df = pd.DataFrame.from_dict(ted_dict, orient='index')
        return df

# %% [markdown]
# # Get Data

# %%
# english
scraper_en = TEDscraper()
ted_dict = scraper_en.get_data()
# Out:
# Fetching urls...
#
# Removed the following 6 urls as they have known issues:
#  ['https://www.ted.com/talks/marilyn_waring_the_unpaid_work_that_gdp_ignores_and_why_it_really_counts/transcript?language=en', 'https://www.ted.com/talks/marcus_bullock_an_app_that_helps_incarcerated_people_stay_connected_to_their_families/transcript?language=en', 'https://www.ted.com/talks/zohreh_davoudi_are_we_living_in_a_simulation/transcript?language=en', 'https://www.ted.com/talks/maisie_williams_why_talent_carries_you_further_than_fame/transcript?language=en', 'https://www.ted.com/talks/keith_lowe_why_we_need_to_stop_obsessing_over_world_war_ii/transcript?language=en', 'https://www.ted.com/talks/anton_garcia_abril_how_prefab_homes_can_transform_affordable_housing/transcript?language=en']
#
# Scraping 3998 TED talks in 'English'...
# Estimated time to complete is 60.0 minutes
#
# [OK] 0 https://www.ted.com/talks/dick_m_carpenter_ii_how_policing_for_profit_undermines_your_rights/transcript?language=en
# [OK] 1 https://www.ted.com/talks/stefan_c_dombrowski_the_dark_history_of_iq_tests/transcript?language=en
# [OK] 2 https://www.ted.com/talks/nancy_lublin_crisis_support_for_the_world_one_text_away/transcript?language=en
# [OK] 3 https://www.ted.com/talks/larry_brilliant_a_global_pandemic_calls_for_global_solutions/transcript?language=en
# [OK] 4 https://www.ted.com/talks/stefan_al_what_happens_if_you_cut_down_all_of_a_city_s_trees/transcript?language=en
# [EXCEPTION] 'NoneType' object has no attribute 'group' https://www.ted.com/talks/arturs_miksons_the_benefits_of_expressing_your_emotions_constructively/transcript?language=en
# [OK] 5 https://www.ted.com/talks/angel_chang_the_wildly_complex_anatomy_of_a_sneaker/transcript?language=en
# [OK] 6 https://www.ted.com/talks/tom_rivett_carnac_how_to_shift_your_mindset_and_choose_your_future/transcript?language=en
# [OK] 7 https://www.ted.com/talks/oliver_jeffers_an_ode_to_living_on_earth/transcript?language=en
# [OK] 8 https://www.ted.com/talks/elizabeth_camarillo_gutierrez_what_s_missing_from_the_american_immigrant_narrative/transcript?language=en
# [OK] 9 https://www.ted.com/talks/lara_durgavich_an_evolutionary_perspective_on_human_health_and_disease/transcript?language=en
# [OK] 10 https://www.ted.com/talks/ming_luke_what_s_the_point_e_of_ballet/transcript?language=en
# [OK] 11 https://www.ted.com/talks/ebony_roberts_and_shaka_senghor_how_to_co_parent_as_allies_not_adversaries/transcript?language=en
# [OK] 12 https://www.ted.com/talks/alex_rosenthal_the_gauntlet_think_like_a_coder_ep_8/transcript?language=en
# [OK] 13 https://www.ted.com/talks/heather_c_mcghee_racism_has_a_cost_for_everyone/transcript?language=en
# [OK] 14 https://www.ted.com/talks/nadya_mason_how_to_spark_your_curiosity_scientifically/transcript?language=en
# [OK] 15 https://www.ted.com/talks/george_zaidan_the_bug_that_poops_candy/transcript?language=en
# [OK] 16 https://www.ted.com/talks/riche_d_richardson_the_hidden_life_of_rosa_parks/transcript?language=en
# [OK] 17 https://www.ted.com/talks/janet_iwasa_the_wonders_of_the_molecular_world_animated/transcript?language=en
# [OK] 18 https://www.ted.com/talks/karin_oberg_the_galactic_recipe_for_a_living_planet/transcript?language=en
# [OK] 19 https://www.ted.com/talks/ray_dalio_what_coronavirus_means_for_the_global_economy/transcript?language=en
# [OK] 20 https://www.ted.com/talks/judy_grisel_how_does_alcohol_make_you_drunk/transcript?language=en
# [OK] 21 https://www.ted.com/talks/jeannie_suk_gersen_how_understanding_divorce_can_help_your_marriage/transcript?language=en
# [OK] 22 https://www.ted.com/talks/lindsay_morcom_a_history_of_indigenous_languages_and_how_to_revitalize_them/transcript?language=en
# [OK] 23 https://www.ted.com/talks/shunan_teng_how_the_monkey_king_escaped_the_underworld/transcript?language=en
# [OK] 24 https://www.ted.com/talks/danielle_allen_an_ethical_plan_for_ending_the_pandemic_and_restarting_the_economy/transcript?language=en
# [OK] 25 https://www.ted.com/talks/noah_charney_the_art_forger_who_tricked_the_nazis/transcript?language=en
# [OK] 26 https://www.ted.com/talks/yifat_susskind_in_uncertain_times_think_like_a_mother/transcript?language=en
# [OK] 27 https://www.ted.com/talks/alexandra_auer_the_intangible_effects_of_walls_apr_2020/transcript?language=en
# [OK] 28 https://www.ted.com/talks/elizabeth_gilbert_it_s_ok_to_feel_overwhelmed_here_s_what_to_do_next/transcript?language=en
# [OK] 29 https://www.ted.com/talks/ethan_lisi_what_it_s_really_like_to_have_autism/transcript?language=en
# [OK] 30 https://www.ted.com/talks/daniel_finkel_can_you_solve_the_sea_monster_riddle/transcript?language=en
# [OK] 31 https://www.ted.com/talks/mary_ellen_hannibal_how_you_can_help_save_the_monarch_butterfly_and_the_planet/transcript?language=en
# [OK] 32 https://www.ted.com/talks/todd_dufresne_history_vs_sigmund_freud/transcript?language=en
# [OK] 33 https://www.ted.com/talks/martha_minow_how_forgiveness_can_create_a_more_just_legal_system/transcript?language=en
# [OK] 34 https://www.ted.com/talks/alex_gendler_how_the_world_s_longest_underwater_tunnel_was_built/transcript?language=en
# [OK] 35 https://www.ted.com/talks/seth_berkley_the_quest_for_the_coronavirus_vaccine/transcript?language=en
# [OK] 36 https://www.ted.com/talks/hindou_oumarou_ibrahim_indigenous_knowledge_meets_science_to_solve_climate_change/transcript?language=en
# [OK] 37 https://www.ted.com/talks/gary_liu_what_the_world_can_learn_from_china_s_response_to_the_coronavirus/transcript?language=en
# [OK] 38 https://www.ted.com/talks/anees_bahji_what_is_schizophrenia/transcript?language=en
# [OK] 39 https://www.ted.com/talks/noeline_kirabo_2_questions_to_uncover_your_passion_and_turn_it_into_a_career/transcript?language=en
# [OK] 40 https://www.ted.com/talks/bill_gates_how_we_must_respond_to_the_coronavirus_pandemic/transcript?language=en
# [OK] 41 https://www.ted.com/talks/johanna_figueira_simple_effective_tech_to_connect_communities_in_crisis/transcript?language=en
# [OK] 42 https://www.ted.com/talks/stefan_al_why_isn_t_the_netherlands_underwater/transcript?language=en
# [OK] 43 https://www.ted.com/talks/david_lindell_a_camera_that_can_see_around_corners/transcript?language=en
# [OK] 44 https://www.ted.com/talks/soraya_field_fiorio_who_was_the_world_s_first_author/transcript?language=en
# [OK] 45 https://www.ted.com/talks/molly_webster_the_weird_history_of_the_sex_chromosomes/transcript?language=en
# [OK] 46 https://www.ted.com/talks/charlie_jane_anders_go_ahead_dream_about_the_future/transcript?language=en
# [OK] 47 https://www.ted.com/talks/matteo_salvadore_the_imaginary_king_who_changed_the_real_world/transcript?language=en
# [OK] 48 https://www.ted.com/talks/angie_murimirwa_how_repaying_loans_with_social_service_transforms_communities/transcript?language=en
# [OK] 49 https://www.ted.com/talks/eric_sannerud_without_farmers_you_d_be_hungry_naked_and_sober_apr_2020/transcript?language=en
# [OK] 50 https://www.ted.com/talks/mark_lytle_how_one_scientist_took_on_the_chemical_industry/transcript?language=en
# [OK] 51 https://www.ted.com/talks/lucy_farey_jones_a_fascinating_time_capsule_of_human_feelings_toward_ai/transcript?language=en
# [OK] 52 https://www.ted.com/talks/alanna_shaikh_why_covid_19_is_hitting_us_now_and_how_to_prepare_for_the_next_outbreak/transcript?language=en
# [OK] 53 https://www.ted.com/talks/adam_kucharski_how_can_we_control_the_coronavirus_pandemic/transcript?language=en
# [OK] 54 https://www.ted.com/talks/gerry_wright_how_can_we_solve_the_antibiotic_resistance_crisis/transcript?language=en
# [OK] 55 https://www.ted.com/talks/ananya_grover_a_campaign_for_period_positivity/transcript?language=en
# [OK] 56 https://www.ted.com/talks/david_wallace_wells_how_we_could_change_the_planet_s_climate_future/transcript?language=en
# [OK] 57 https://www.ted.com/talks/jim_hudspeth_the_beautiful_mysterious_science_of_how_you_hear/transcript?language=en
# [OK] 58 https://www.ted.com/talks/rosario_perazolo_masjoan_cuando_te_importa_mi_silla_de_ruedas/transcript?language=en
# [OK] 59 https://www.ted.com/talks/iseult_gillespie_the_tale_of_the_doctor_who_defied_death/transcript?language=en
# [OK] 60 https://www.ted.com/talks/elizabeth_stordeur_pryor_why_it_s_so_hard_to_talk_about_the_n_word/transcript?language=en
# [OK] 61 https://www.ted.com/talks/nicola_jones_the_dangers_of_a_noisy_ocean_and_how_we_can_quiet_it_down/transcript?language=en
# [OK] 62 https://www.ted.com/talks/iseult_gillespie_the_meaning_of_life_according_to_simone_de_beauvoir/transcript?language=en
# [OK] 63 https://www.ted.com/talks/lisa_mosconi_how_menopause_affects_the_brain/transcript?language=en
# [OK] 64 https://www.ted.com/talks/matt_cutts_what_happens_when_a_silicon_valley_technologist_works_for_the_government/transcript?language=en
# [OK] 65 https://www.ted.com/talks/ming_luke_what_s_a_squillo_and_why_do_opera_singers_need_it/transcript?language=en
# [OK] 66 https://www.ted.com/talks/france_villarta_the_gender_fluid_history_of_the_philippines/transcript?language=en
# [OK] 67 https://www.ted.com/talks/agnes_binagwaho_how_women_are_revolutionizing_rwanda/transcript?language=en
# [OK] 68 https://www.ted.com/talks/matt_porter_and_margaret_hamilton_how_one_woman_put_man_on_the_moon/transcript?language=en
# [OK] 69 https://www.ted.com/talks/kay_m_tye_what_investigating_neural_pathways_can_reveal_about_mental_health/transcript?language=en
# [OK] 70 https://www.ted.com/talks/jill_seubert_how_a_miniaturized_atomic_clock_could_revolutionize_space_exploration/transcript?language=en
# [OK] 71 https://www.ted.com/talks/jiabao_li_art_that_reveals_how_technology_frames_reality/transcript?language=en
# [OK] 72 https://www.ted.com/talks/david_heymann_what_we_do_and_don_t_know_about_the_coronavirus/transcript?language=en
# [OK] 73 https://www.ted.com/talks/alex_gendler_can_you_solve_the_death_race_riddle/transcript?language=en
# [OK] 74 https://www.ted.com/talks/chuck_plunkett_when_local_news_dies_so_does_democracy/transcript?language=en
# [OK] 75 https://www.ted.com/talks/alex_gendler_the_egyptian_myth_of_isis_and_the_seven_scorpions/transcript?language=en
# [OK] 76 https://www.ted.com/talks/renee_lertzman_how_to_turn_climate_anxiety_into_action/transcript?language=en
# [OK] 77 https://www.ted.com/talks/eva_galperin_what_you_need_to_know_about_stalkerware/transcript?language=en
# [OK] 78 https://www.ted.com/talks/alex_rosenthal_the_tower_of_epiphany_think_like_a_coder_ep_7/transcript?language=en
# [OK] 79 https://www.ted.com/talks/amanda_schochet_how_bumble_bees_inspired_a_network_of_tiny_museums/transcript?language=en
# [OK] 80 https://www.ted.com/talks/wanjira_mathai_3_ways_to_uproot_a_culture_of_corruption/transcript?language=en
# [OK] 81 https://www.ted.com/talks/rebecca_knill_how_technology_has_changed_what_it_s_like_to_be_deaf/transcript?language=en
# [OK] 82 https://www.ted.com/talks/sara_sanford_how_to_design_gender_bias_out_of_your_workplace/transcript?language=en
# [OK] 83 https://www.ted.com/talks/gerd_gigerenzer_why_do_people_fear_the_wrong_things/transcript?language=en
# [OK] 84 https://www.ted.com/talks/fang_ruan_management_lessons_from_chinese_business_and_philosophy/transcript?language=en
# [OK] 85 https://www.ted.com/talks/kenny_coogan_vultures_the_acid_puking_plague_busting_heroes_of_the_ecosystem/transcript?language=en
# [OK] 86 https://www.ted.com/talks/kristen_wenz_what_if_a_single_human_right_could_change_the_world/transcript?language=en
# [OK] 87 https://www.ted.com/talks/curtis_austin_the_real_story_of_the_black_panther_party/transcript?language=en
# [OK] 88 https://www.ted.com/talks/diego_prilusky_how_volumetric_video_brings_a_new_dimension_to_filmmaking/transcript?language=en
# [OK] 89 https://www.ted.com/talks/jesse_byock_the_secret_messages_of_viking_runestones/transcript?language=en
# [OK] 90 https://www.ted.com/talks/jennifer_zhu_scott_why_you_should_get_paid_for_your_data/transcript?language=en
# [OK] 91 https://www.ted.com/talks/bill_schutt_how_do_blood_transfusions_work/transcript?language=en
# [OK] 92 https://www.ted.com/talks/maria_neira_this_is_your_brain_on_air_pollution/transcript?language=en
# [OK] 93 https://www.ted.com/talks/joel_leon_the_beautiful_hard_work_of_co_parenting/transcript?language=en
# [OK] 94 https://www.ted.com/talks/lauren_sallan_a_brief_tour_of_the_last_4_billion_years_dinosaurs_not_included/transcript?language=en
# [OK] 95 https://www.ted.com/talks/yve_blake_for_the_love_of_fangirls/transcript?language=en
# [OK] 96 https://www.ted.com/talks/yves_behar_how_surfboards_connect_us_to_nature/transcript?language=en
# [OK] 97 https://www.ted.com/talks/jon_gray_the_power_of_the_afro_pick/transcript?language=en
# [OK] 98 https://www.ted.com/talks/chip_kidd_why_books_are_here_to_stay/transcript?language=en
# [OK] 99 https://www.ted.com/talks/jennifer_8_lee_why_1_5_billion_people_eat_with_chopsticks/transcript?language=en
# [OK] 100 https://www.ted.com/talks/debbie_millman_the_function_and_fashion_of_eyeglasses/transcript?language=en
# [OK] 101 https://www.ted.com/talks/david_biello_how_the_compass_unlocked_the_world/transcript?language=en
# [EXCEPTION] 'NoneType' object has no attribute 'group' https://www.ted.com/talks/a_j_jacobs_the_evolution_of_the_coffee_cup_lid/transcript?language=en
# [OK] 102 https://www.ted.com/talks/paola_antonelli_why_pasta_comes_in_all_shapes_and_sizes/transcript?language=en
# [OK] 103 https://www.ted.com/talks/debbie_millman_how_symbols_and_brands_shape_our_humanity/transcript?language=en
# [OK] 104 https://www.ted.com/talks/noelle_martin_online_predators_spread_fake_porn_of_me_here_s_how_i_fought_back/transcript?language=en
# [OK] 105 https://www.ted.com/talks/antara_raychaudhuri_and_iseult_gillespie_the_legend_of_annapurna_hindu_goddess_of_nourishment/transcript?language=en
# [OK] 106 https://www.ted.com/talks/victoria_gill_what_a_nun_can_teach_a_scientist_about_ecology/transcript?language=en
# [OK] 107 https://www.ted.com/talks/lisa_godwin_how_teachers_can_help_students_navigate_trauma/transcript?language=en
# [OK] 108 https://www.ted.com/talks/alex_gendler_epic_engineering_building_the_brooklyn_bridge/transcript?language=en
# [OK] 109 https://www.ted.com/talks/amane_dannouni_how_online_marketplaces_can_help_local_economies_not_hurt_them/transcript?language=en
# [OK] 110 https://www.ted.com/talks/allison_ramsey_and_mary_staicu_the_accident_that_changed_the_world/transcript?language=en
# [OK] 111 https://www.ted.com/talks/alicia_eggert_imaginative_sculptures_that_explore_how_we_perceive_reality/transcript?language=en
# [OK] 112 https://www.ted.com/talks/robert_reffkin_5_ways_to_create_stronger_connections/transcript?language=en
# [OK] 113 https://www.ted.com/talks/chieh_huang_how_to_know_if_it_s_time_to_change_careers/transcript?language=en
# [OK] 114 https://www.ted.com/talks/emily_oster_3_things_new_parents_should_consider_before_going_back_to_work/transcript?language=en
# [OK] 115 https://www.ted.com/talks/thasunda_duckett_6_ways_to_improve_your_relationship_with_money/transcript?language=en
# [OK] 116 https://www.ted.com/talks/leeann_renninger_the_secret_to_giving_great_feedback/transcript?language=en
# [OK] 117 https://www.ted.com/talks/liz_fosslien_how_to_embrace_emotions_at_work/transcript?language=en
# [OK] 118 https://www.ted.com/talks/rahaf_harfoush_how_burnout_makes_us_less_creative/transcript?language=en
# [OK] 119 https://www.ted.com/talks/patrick_mcginnis_how_to_make_faster_decisions/transcript?language=en
# [OK] 120 https://www.ted.com/talks/alex_gendler_everything_changed_when_the_fire_crystal_got_stolen/transcript?language=en
# [OK] 121 https://www.ted.com/talks/lucy_king_how_bees_can_keep_the_peace_between_elephants_and_humans/transcript?language=en
# [OK] 122 https://www.ted.com/talks/smruti_jukur_johari_what_if_the_poor_were_part_of_city_planning/transcript?language=en
# [OK] 123 https://www.ted.com/talks/jennifer_vail_the_science_of_friction_and_its_surprising_impact_on_our_lives/transcript?language=en
# [OK] 124 https://www.ted.com/talks/matthew_a_wilson_the_health_benefits_of_clowning_around/transcript?language=en
# [OK] 125 https://www.ted.com/talks/jay_van_bavel_do_politics_make_us_irrational/transcript?language=en
# [OK] 126 https://www.ted.com/talks/paul_mceuen_and_marc_miskin_tiny_robots_with_giant_potential/transcript?language=en
# [OK] 127 https://www.ted.com/talks/lisa_janae_bacon_the_life_legacy_assassination_of_an_african_revolutionary/transcript?language=en
# [OK] 128 https://www.ted.com/talks/david_ikard_the_real_story_of_rosa_parks_and_why_we_need_to_confront_myths_about_black_history/transcript?language=en
# [OK] 129 https://www.ted.com/talks/rayma_suprani_dictators_hate_political_cartoons_so_i_keep_drawing_them/transcript?language=en
# [OK] 130 https://www.ted.com/talks/alex_rosenthal_the_chasm_think_like_a_coder_ep_6/transcript?language=en
# [OK] 131 https://www.ted.com/talks/ellen_agler_parasitic_worms_hold_back_human_progress_here_s_how_we_can_end_them/transcript?language=en
# [OK] 132 https://www.ted.com/talks/sylvain_duranton_how_humans_and_ai_can_work_together_to_create_better_businesses/transcript?language=en
# [OK] 133 https://www.ted.com/talks/jessica_ochoa_hendrix_how_virtual_reality_turns_students_into_scientists/transcript?language=en
# [OK] 134 https://www.ted.com/talks/christopher_bahl_a_new_type_of_medicine_custom_made_with_tiny_proteins/transcript?language=en
# [OK] 135 https://www.ted.com/talks/kenny_coogan_licking_bees_and_pulping_trees_the_reign_of_a_wasp_queen/transcript?language=en
# [OK] 136 https://www.ted.com/talks/melody_smith_how_bones_make_blood/transcript?language=en
# [OK] 137 https://www.ted.com/talks/werner_reich_how_the_magic_of_kindness_helped_me_survive_the_holocaust/transcript?language=en
# [OK] 138 https://www.ted.com/talks/angelicque_white_what_ocean_microbes_reveal_about_the_changing_climate/transcript?language=en
# [OK] 139 https://www.ted.com/talks/michael_r_stiff_why_is_cotton_in_everything/transcript?language=en
# [OK] 140 https://www.ted.com/talks/erin_sullivan_does_photographing_a_moment_steal_the_experience_from_you/transcript?language=en
# [OK] 141 https://www.ted.com/talks/priscilla_pemu_a_personal_health_coach_for_those_living_with_chronic_diseases/transcript?language=en
# [OK] 142 https://www.ted.com/talks/stuart_oda_are_indoor_vertical_farms_the_future_of_agriculture/transcript?language=en
# [OK] 143 https://www.ted.com/talks/jan_bill_what_was_so_special_about_viking_ships/transcript?language=en
# [OK] 144 https://www.ted.com/talks/adam_garske_how_designing_brand_new_enzymes_could_change_the_world/transcript?language=en
# [OK] 145 https://www.ted.com/talks/jen_gunter_why_can_t_we_talk_about_periods/transcript?language=en
# [OK] 146 https://www.ted.com/talks/rachel_kleinfeld_a_path_to_security_for_the_world_s_deadliest_countries/transcript?language=en
# [OK] 147 https://www.ted.com/talks/walter_r_tschinkel_mating_frenzies_sperm_hoards_and_brood_raids_the_life_of_a_fire_ant_queen/transcript?language=en
# [OK] 148 https://www.ted.com/talks/priti_krishtel_why_are_drug_prices_so_high_investigating_the_outdated_us_patent_system/transcript?language=en
# [OK] 149 https://www.ted.com/talks/markus_mutz_how_supply_chain_transparency_can_help_the_planet/transcript?language=en
# [OK] 150 https://www.ted.com/talks/david_j_bier_how_guest_worker_visas_could_transform_the_us_immigration_system/transcript?language=en
# [OK] 151 https://www.ted.com/talks/tom_nash_the_perks_of_being_a_pirate_feb_2019/transcript?language=en
# [OK] 152 https://www.ted.com/talks/alex_rosenthal_the_artists_think_like_a_coder_ep_5/transcript?language=en
# [OK] 153 https://www.ted.com/talks/suzanne_lee_why_biofabrication_is_the_next_industrial_revolution/transcript?language=en
# [OK] 154 https://www.ted.com/talks/marco_tempest_a_swarm_of_mini_drones_makes_magic/transcript?language=en
# [OK] 155 https://www.ted.com/talks/alex_gendler_can_you_solve_the_dragon_jousting_riddle/transcript?language=en
# [OK] 156 https://www.ted.com/talks/colette_pichon_battle_climate_change_will_displace_millions_here_s_how_we_prepare/transcript?language=en
# [OK] 157 https://www.ted.com/talks/anna_piperal_what_a_digital_government_looks_like/transcript?language=en
# [OK] 158 https://www.ted.com/talks/eden_girma_the_mysterious_life_and_death_of_rasputin/transcript?language=en
# [OK] 159 https://www.ted.com/talks/emma_schachner_the_secret_weapon_that_let_dinosaurs_take_over_the_planet/transcript?language=en
# [OK] 160 https://www.ted.com/talks/leon_marchal_the_urgent_case_for_antibiotic_free_animals/transcript?language=en
# [OK] 161 https://www.ted.com/talks/julian_burschka_could_a_breathalyzer_detect_cancer/transcript?language=en
# [OK] 162 https://www.ted.com/talks/risa_wechsler_the_search_for_dark_matter_and_what_we_ve_found_so_far/transcript?language=en
# [OK] 163 https://www.ted.com/talks/mitch_zeller_the_past_present_and_future_of_nicotine_addiction/transcript?language=en
# [OK] 164 https://www.ted.com/talks/anindya_kundu_the_opportunity_gap_in_us_public_education_and_how_to_close_it/transcript?language=en
# [OK] 165 https://www.ted.com/talks/ipsita_dasgupta_to_challenge_the_status_quo_find_a_co_conspirator/transcript?language=en
# [OK] 166 https://www.ted.com/talks/rod_phillips_a_brief_history_of_alcohol/transcript?language=en
# [OK] 167 https://www.ted.com/talks/pat_mitchell_dangerous_times_call_for_dangerous_women/transcript?language=en
# [OK] 168 https://www.ted.com/talks/cara_e_yar_khan_the_beautiful_balance_between_courage_and_fear/transcript?language=en
# [OK] 169 https://www.ted.com/talks/valorie_kondos_field_why_winning_doesn_t_always_equal_success/transcript?language=en
# [OK] 170 https://www.ted.com/talks/guy_winch_how_to_turn_off_work_thoughts_during_your_free_time/transcript?language=en
# [OK] 171 https://www.ted.com/talks/william_d_desmond_the_philosophy_of_cynicism/transcript?language=en
# [OK] 172 https://www.ted.com/talks/nick_bostrom_how_civilization_could_destroy_itself_and_4_ways_we_could_prevent_it/transcript?language=en
# [OK] 173 https://www.ted.com/talks/diego_prilusky_como_sera_el_cine_del_futuro/transcript?language=en
# [OK] 174 https://www.ted.com/talks/jasmine_crowe_what_we_re_getting_wrong_in_the_fight_to_end_hunger/transcript?language=en
# [OK] 175 https://www.ted.com/talks/sinan_aral_how_we_can_protect_truth_in_the_age_of_misinformation/transcript?language=en
# [OK] 176 https://www.ted.com/talks/dan_kwartler_why_should_you_read_dune_by_frank_herbert/transcript?language=en
# [OK] 177 https://www.ted.com/talks/enrico_ramirez_ruiz_your_body_was_forged_in_the_spectacular_death_of_stars/transcript?language=en
# [OK] 178 https://www.ted.com/talks/sheila_marie_orfano_why_should_you_read_the_joy_luck_club_by_amy_tan/transcript?language=en
# [OK] 179 https://www.ted.com/talks/henna_maria_uusitupa_how_the_gut_microbes_you_re_born_with_affect_your_lifelong_health/transcript?language=en
# [OK] 180 https://www.ted.com/talks/kelsey_leonard_why_lakes_and_rivers_should_have_the_same_rights_as_humans/transcript?language=en
# [OK] 181 https://www.ted.com/talks/bright_simons_to_help_solve_global_problems_look_to_developing_countries/transcript?language=en
# [OK] 182 https://www.ted.com/talks/jill_dash_why_should_you_read_lord_of_the_flies_by_william_golding/transcript?language=en
# [OK] 183 https://www.ted.com/talks/lorna_davis_a_guide_to_collaborative_leadership/transcript?language=en
# [OK] 184 https://www.ted.com/talks/christiana_figueres_and_chris_anderson_how_we_can_turn_the_tide_on_climate/transcript?language=en
# [OK] 185 https://www.ted.com/talks/tal_danino_hacking_bacteria_to_fight_cancer/transcript?language=en
# [OK] 186 https://www.ted.com/talks/mariana_mazzucato_what_is_economic_value_and_who_creates_it/transcript?language=en
# [OK] 187 https://www.ted.com/talks/edward_tenner_the_paradox_of_efficiency/transcript?language=en
# [OK] 188 https://www.ted.com/talks/jane_fonda_why_i_protest_for_climate_justice/transcript?language=en
# [OK] 189 https://www.ted.com/talks/kathryn_bouskill_the_unforeseen_consequences_of_a_fast_paced_world/transcript?language=en
# [OK] 190 https://www.ted.com/talks/alex_rosenthal_the_train_heist_think_like_a_coder_ep_4/transcript?language=en
# [OK] 191 https://www.ted.com/talks/eve_ensler_the_profound_power_of_an_authentic_apology/transcript?language=en
# [OK] 192 https://www.ted.com/talks/hyunsoo_joshua_no_how_does_chemotherapy_work/transcript?language=en
# [OK] 193 https://www.ted.com/talks/cornelia_geppert_a_video_game_that_helps_us_understand_loneliness/transcript?language=en
# [OK] 194 https://www.ted.com/talks/kelsey_johnson_the_problem_of_light_pollution_and_5_ridiculously_easy_ways_to_fix_it/transcript?language=en
# [OK] 195 https://www.ted.com/talks/alex_gendler_why_doesn_t_the_leaning_tower_of_pisa_fall_over/transcript?language=en
# [OK] 196 https://www.ted.com/talks/kara_logan_berlin_3_ways_to_be_a_more_effective_fundraiser/transcript?language=en
# [OK] 197 https://www.ted.com/talks/heidi_boisvert_how_i_m_using_biological_data_to_tell_better_stories_and_spark_social_change/transcript?language=en
# [OK] 198 https://www.ted.com/talks/chris_a_kniesly_how_corn_conquered_the_world/transcript?language=en
# [OK] 199 https://www.ted.com/talks/anees_bahji_is_marijuana_bad_for_your_brain/transcript?language=en
# [OK] 200 https://www.ted.com/talks/alejandro_duran_how_i_use_art_to_tackle_plastic_pollution_in_our_oceans/transcript?language=en
# [OK] 201 https://www.ted.com/talks/cathy_mulzer_the_incredible_chemistry_powering_your_smartphone/transcript?language=en
# [OK] 202 https://www.ted.com/talks/mike_cannon_brookes_how_you_can_use_impostor_syndrome_to_your_benefit/transcript?language=en
# [OK] 203 https://www.ted.com/talks/deepa_narayan_7_beliefs_that_can_silence_women_and_how_to_unlearn_them/transcript?language=en
# [OK] 204 https://www.ted.com/talks/alex_gendler_can_you_outsmart_this_logical_fallacy/transcript?language=en
# [OK] 205 https://www.ted.com/talks/sougwen_chung_why_i_draw_with_robots/transcript?language=en
# [OK] 206 https://www.ted.com/talks/mike_brown_the_search_for_our_solar_system_s_ninth_planet/transcript?language=en
# [OK] 207 https://www.ted.com/talks/theresa_a_yugar_history_s_worst_nun/transcript?language=en
# [OK] 208 https://www.ted.com/talks/daniel_bogre_udell_how_to_save_a_language_from_extinction/transcript?language=en
# [OK] 209 https://www.ted.com/talks/latoya_ruby_frazier_a_creative_solution_for_the_water_crisis_in_flint_michigan/transcript?language=en
# [OK] 210 https://www.ted.com/talks/emma_belcher_3_questions_we_should_ask_about_nuclear_weapons/transcript?language=en
# [OK] 211 https://www.ted.com/talks/dan_reinstein_how_does_laser_eye_surgery_work/transcript?language=en
# [OK] 212 https://www.ted.com/talks/david_asch_why_it_s_so_hard_to_make_healthy_decisions/transcript?language=en
# [OK] 213 https://www.ted.com/talks/arunabha_ghosh_5_steps_for_clean_air_in_india/transcript?language=en
# [OK] 214 https://www.ted.com/talks/alex_rosenthal_the_furnace_bots_think_like_a_coder_ep_3/transcript?language=en
# [OK] 215 https://www.ted.com/talks/guadalupe_nogues_como_hablar_con_otros_que_piensan_distinto/transcript?language=en
# [OK] 216 https://www.ted.com/talks/dan_ariely_how_to_change_your_behavior_for_the_better/transcript?language=en
# [OK] 217 https://www.ted.com/talks/gaby_barrios_why_gender_based_marketing_is_bad_for_business/transcript?language=en
# [OK] 218 https://www.ted.com/talks/alex_gendler_the_myth_of_loki_and_the_master_builder/transcript?language=en
# [OK] 219 https://www.ted.com/talks/erika_pinheiro_what_s_really_happening_at_the_us_mexico_border_and_how_we_can_do_better/transcript?language=en
# [OK] 220 https://www.ted.com/talks/sydney_jensen_how_can_we_support_the_emotional_well_being_of_teachers/transcript?language=en
# [OK] 221 https://www.ted.com/talks/cady_coleman_what_it_s_like_to_live_on_the_international_space_station/transcript?language=en
# [OK] 222 https://www.ted.com/talks/craig_costello_in_the_war_for_information_will_quantum_computers_defeat_cryptographers/transcript?language=en
# [OK] 223 https://www.ted.com/talks/peter_beck_small_rockets_are_the_next_space_revolution/transcript?language=en
# [OK] 224 https://www.ted.com/talks/celine_valery_the_dangers_of_mixing_drugs/transcript?language=en
# [OK] 225 https://www.ted.com/talks/mani_vajipey_how_india_s_local_recyclers_could_solve_plastic_pollution/transcript?language=en
# [OK] 226 https://www.ted.com/talks/dorsa_amir_why_do_humans_have_a_third_eyelid/transcript?language=en
# [OK] 227 https://www.ted.com/talks/rabiaa_el_garani_hope_and_justice_for_women_who_ve_survived_isis/transcript?language=en
# [OK] 228 https://www.ted.com/talks/kaitlyn_sadtler_and_heather_j_faust_why_haven_t_we_cured_arthritis/transcript?language=en
# [OK] 229 https://www.ted.com/talks/amma_y_ghartey_tagoe_kootin_a_historical_musical_that_examines_black_identity_in_the_1901_world_s_fair/transcript?language=en
# [OK] 230 https://www.ted.com/talks/ma_yansong_urban_architecture_inspired_by_mountains_clouds_and_volcanoes/transcript?language=en
# [OK] 231 https://www.ted.com/talks/eli_pariser_what_obligation_do_social_media_platforms_have_to_the_greater_good/transcript?language=en
# [OK] 232 https://www.ted.com/talks/paul_a_kramer_our_immigration_conversation_is_broken_here_s_how_to_have_a_better_one/transcript?language=en
# [OK] 233 https://www.ted.com/talks/laura_rovner_what_happens_to_people_in_solitary_confinement/transcript?language=en
# [OK] 234 https://www.ted.com/talks/lucas_husted_game_theory_challenge_can_you_predict_human_behavior/transcript?language=en
# [OK] 235 https://www.ted.com/talks/tashka_and_laura_yawanawa_the_amazon_belongs_to_humanity_let_s_protect_it_together/transcript?language=en
# [OK] 236 https://www.ted.com/talks/bhakti_sharma_what_open_water_swimming_taught_me_about_resilience/transcript?language=en
# [OK] 237 https://www.ted.com/talks/bill_keegan_the_taino_myth_of_the_cursed_creator/transcript?language=en
# [OK] 238 https://www.ted.com/talks/bob_langert_the_business_case_for_working_with_your_toughest_critics/transcript?language=en
# [OK] 239 https://www.ted.com/talks/sara_jane_dunn_the_next_software_revolution_programming_biological_cells/transcript?language=en
# [OK] 240 https://www.ted.com/talks/lori_gottlieb_how_changing_your_story_can_change_your_life/transcript?language=en
# [OK] 241 https://www.ted.com/talks/chip_berlet_are_the_illuminati_real/transcript?language=en
# [OK] 242 https://www.ted.com/talks/daniel_streicker_what_vaccinating_vampire_bats_can_teach_us_about_pandemics/transcript?language=en
# [OK] 243 https://www.ted.com/talks/jess_kutch_what_productive_conflict_can_offer_a_workplace/transcript?language=en
# [OK] 244 https://www.ted.com/talks/jacob_soboroff_why_do_americans_vote_on_tuesdays/transcript?language=en
# [OK] 245 https://www.ted.com/talks/toby_kiers_lessons_from_fungi_on_markets_and_economics/transcript?language=en
# [OK] 246 https://www.ted.com/talks/hans_block_and_moritz_riesewieck_the_price_of_a_clean_internet/transcript?language=en
# [OK] 247 https://www.ted.com/talks/leila_pirhaji_the_medical_potential_of_ai_and_metabolites/transcript?language=en
# [OK] 248 https://www.ted.com/talks/matthew_borths_claws_vs_nails/transcript?language=en
# [OK] 249 https://www.ted.com/talks/michael_s_a_graziano_how_close_are_we_to_uploading_our_minds/transcript?language=en
# [OK] 250 https://www.ted.com/talks/alisa_kazarina_humanity_at_the_intersection_of_science_and_archaeology/transcript?language=en
# [OK] 251 https://www.ted.com/talks/alyssa_loorya_what_i_learned_from_digging_under_new_york_city_s_streets/transcript?language=en
# [OK] 252 https://www.ted.com/talks/rose_m_mutiso_how_to_bring_affordable_sustainable_electricity_to_africa/transcript?language=en
# [OK] 253 https://www.ted.com/talks/beau_lotto_and_cirque_du_soleil_how_we_experience_awe_and_why_it_matters/transcript?language=en
# [OK] 254 https://www.ted.com/talks/claire_wardle_how_you_can_help_transform_the_internet_into_a_place_of_trust/transcript?language=en
# [OK] 255 https://www.ted.com/talks/adrienne_mayor_the_greek_myth_of_talos_the_first_robot/transcript?language=en
# [OK] 256 https://www.ted.com/talks/ashwin_naidu_the_link_between_fishing_cats_and_mangrove_forest_conservation/transcript?language=en
# [OK] 257 https://www.ted.com/talks/jon_m_chu_the_pride_and_power_of_representation_in_film/transcript?language=en
# [OK] 258 https://www.ted.com/talks/abhishek_gopalka_how_motivation_can_fix_public_systems/transcript?language=en
# [OK] 259 https://www.ted.com/talks/fabio_pacucci_hawking_s_black_hole_paradox_explained/transcript?language=en
# [OK] 260 https://www.ted.com/talks/janelle_shane_the_danger_of_ai_is_weirder_than_you_think/transcript?language=en
# [OK] 261 https://www.ted.com/talks/becca_mccharen_tran_fashion_that_celebrates_all_body_types_boldly_and_unapologetically/transcript?language=en
# [OK] 262 https://www.ted.com/talks/ted_ed_the_maya_myth_of_the_morning_star/transcript?language=en
# [OK] 263 https://www.ted.com/talks/james_logan_how_we_re_using_dogs_to_sniff_out_malaria/transcript?language=en
# [OK] 264 https://www.ted.com/talks/joy_wolfram_how_nanoparticles_could_change_the_way_we_treat_cancer/transcript?language=en
# [OK] 265 https://www.ted.com/talks/ayana_elizabeth_johnson_a_love_story_for_the_coral_reef_crisis/transcript?language=en
# [OK] 266 https://www.ted.com/talks/taneka_jones_how_to_3d_print_human_tissue/transcript?language=en
# [OK] 267 https://www.ted.com/talks/alasdair_harris_how_a_handful_of_fishing_villages_sparked_a_marine_conservation_revolution/transcript?language=en
# [OK] 268 https://www.ted.com/talks/tina_arrowood_a_circular_economy_for_salt_that_keeps_rivers_clean/transcript?language=en
# [OK] 269 https://www.ted.com/talks/esther_meduna_why_our_future_relies_on_the_genetic_diversity_of_food/transcript?language=en
# [OK] 270 https://www.ted.com/talks/richard_coffin_what_causes_an_economic_recession/transcript?language=en
# [OK] 271 https://www.ted.com/talks/luis_h_zayas_the_psychological_impact_of_child_separation_at_the_us_mexico_border/transcript?language=en
# [OK] 272 https://www.ted.com/talks/julie_cordua_how_we_can_eliminate_child_sexual_abuse_material_from_the_internet/transcript?language=en
# [OK] 273 https://www.ted.com/talks/alex_rosenthal_the_resistance_think_like_a_coder_ep_2/transcript?language=en
# [OK] 274 https://www.ted.com/talks/david_deutsch_after_billions_of_years_of_monotony_the_universe_is_waking_up/transcript?language=en
# [OK] 275 https://www.ted.com/talks/judith_jamison_and_members_of_the_alvin_ailey_american_dance_theater_revelations_from_a_lifetime_of_dance/transcript?language=en
# [OK] 276 https://www.ted.com/talks/sheila_marie_orfano_why_should_you_read_dante_s_divine_comedy/transcript?language=en
# [OK] 277 https://www.ted.com/talks/shannon_lee_what_bruce_lee_can_teach_us_about_living_fully/transcript?language=en
# [OK] 278 https://www.ted.com/talks/laura_boykin_how_we_re_using_dna_tech_to_help_farmers_fight_crop_diseases/transcript?language=en
# [OK] 279 https://www.ted.com/talks/juan_enriquez_a_personal_plea_for_humanity_at_the_us_mexico_border/transcript?language=en
# [OK] 280 https://www.ted.com/talks/andrew_forrest_a_radical_plan_to_end_plastic_waste/transcript?language=en
# [OK] 281 https://www.ted.com/talks/gangadhar_patil_how_we_re_helping_local_reporters_turn_important_stories_into_national_news/transcript?language=en
# [OK] 282 https://www.ted.com/talks/herman_narula_the_transformative_power_of_video_games/transcript?language=en
# [OK] 283 https://www.ted.com/talks/marlene_daut_the_first_and_last_king_of_haiti/transcript?language=en
# [OK] 284 https://www.ted.com/talks/tara_djokic_this_ancient_rock_is_changing_our_theory_on_the_origin_of_life/transcript?language=en
# [OK] 285 https://www.ted.com/talks/efosa_ojomo_reducing_corruption_takes_a_specific_kind_of_investment/transcript?language=en
# [OK] 286 https://www.ted.com/talks/david_peterson_why_language_is_humanity_s_greatest_invention/transcript?language=en
# [OK] 287 https://www.ted.com/talks/aracelis_girmay_for_estefani_third_grade_who_made_me_a_card/transcript?language=en
# [OK] 288 https://www.ted.com/talks/camilla_arndal_andersen_what_happens_in_your_brain_when_you_taste_food/transcript?language=en
# [OK] 289 https://www.ted.com/talks/mitchell_katz_what_the_us_health_care_system_assumes_about_you/transcript?language=en
# [OK] 290 https://www.ted.com/talks/densho_ugly_history_japanese_american_incarceration_camps/transcript?language=en
# [OK] 291 https://www.ted.com/talks/moreangels_mbizah_how_community_led_conservation_can_save_wildlife/transcript?language=en
# [OK] 292 https://www.ted.com/talks/mohammad_modarres_why_you_should_shop_at_your_local_farmers_market/transcript?language=en
# [OK] 293 https://www.ted.com/talks/alex_rosenthal_the_prison_break_think_like_a_coder_ep_1/transcript?language=en
# [OK] 294 https://www.ted.com/talks/sarah_sze_how_we_experience_time_and_memory_through_art/transcript?language=en
# [OK] 295 https://www.ted.com/talks/antonio_garcia_vicente_porque_le_enseno_a_ninos_como_yo_a_programar/transcript?language=en
# [OK] 296 https://www.ted.com/talks/muthoni_drummer_queen_creativity_builds_nations/transcript?language=en
# [OK] 297 https://www.ted.com/talks/sam_van_aken_how_one_tree_grows_40_different_kinds_of_fruit/transcript?language=en
# [OK] 298 https://www.ted.com/talks/amber_stuver_einstein_s_twin_paradox_explained/transcript?language=en
# [OK] 299 https://www.ted.com/talks/will_hurd_a_wall_won_t_solve_america_s_border_problems/transcript?language=en
# [OK] 300 https://www.ted.com/talks/yaniv_erlich_how_we_re_building_the_world_s_largest_family_tree/transcript?language=en
# [OK] 301 https://www.ted.com/talks/laura_wright_why_should_you_read_the_god_of_small_things_by_arundhati_roy/transcript?language=en
# [OK] 302 https://www.ted.com/talks/emily_nagoski_how_couples_can_sustain_a_strong_sexual_connection_for_a_lifetime/transcript?language=en
# [OK] 303 https://www.ted.com/talks/hanna_ilona_harmavaara_the_myth_of_the_sampo_an_infinite_source_of_fortune_and_greed/transcript?language=en
# [OK] 304 https://www.ted.com/talks/tim_flannery_can_seaweed_help_curb_global_warming/transcript?language=en
# [OK] 305 https://www.ted.com/talks/safeena_husain_a_bold_plan_to_empower_1_6_million_out_of_school_girls_in_india/transcript?language=en
# [OK] 306 https://www.ted.com/talks/sonaar_luthra_we_need_to_track_the_world_s_water_like_we_track_the_weather/transcript?language=en
# [OK] 307 https://www.ted.com/talks/christer_mjaset_4_questions_you_should_always_ask_your_doctor/transcript?language=en
# [OK] 308 https://www.ted.com/talks/johann_hari_this_could_be_why_you_re_depressed_or_anxious/transcript?language=en
# [OK] 309 https://www.ted.com/talks/federica_bianco_how_we_use_astrophysics_to_study_earthbound_problems/transcript?language=en
# [OK] 310 https://www.ted.com/talks/philip_freeman_a_day_in_the_life_of_an_ancient_celtic_druid/transcript?language=en
# [OK] 311 https://www.ted.com/talks/patrick_chappatte_a_free_world_needs_satire/transcript?language=en
# [OK] 312 https://www.ted.com/talks/kristie_ebi_how_climate_change_could_make_our_food_less_nutritious/transcript?language=en
# [OK] 313 https://www.ted.com/talks/alex_gendler_can_you_solve_the_secret_sauce_riddle/transcript?language=en
# [OK] 314 https://www.ted.com/talks/emmett_shear_what_streaming_means_for_the_future_of_entertainment/transcript?language=en
# [OK] 315 https://www.ted.com/talks/nick_hanauer_the_dirty_secret_of_capitalism_and_a_new_way_forward/transcript?language=en
# [OK] 316 https://www.ted.com/talks/raj_jayadev_community_powered_criminal_justice_reform/transcript?language=en
# [OK] 317 https://www.ted.com/talks/alex_gendler_a_brief_history_of_chess/transcript?language=en
# [OK] 318 https://www.ted.com/talks/jacqueline_woodson_what_reading_slowly_taught_me_about_writing/transcript?language=en
# [OK] 319 https://www.ted.com/talks/danielle_citron_how_deepfakes_undermine_truth_and_threaten_democracy/transcript?language=en
# [OK] 320 https://www.ted.com/talks/sandeep_jauhar_how_your_emotions_change_the_shape_of_your_heart/transcript?language=en
# [OK] 321 https://www.ted.com/talks/iseult_gillespie_why_should_you_read_midnight_s_children/transcript?language=en
# [OK] 322 https://www.ted.com/talks/carl_june_a_living_drug_that_could_change_the_way_we_treat_cancer/transcript?language=en
# [OK] 323 https://www.ted.com/talks/clint_smith_ode_to_the_only_black_kid_in_the_class/transcript?language=en
# [OK] 324 https://www.ted.com/talks/phillip_atiba_goff_how_we_can_make_racism_a_solvable_problem_and_improve_policing/transcript?language=en
# [OK] 325 https://www.ted.com/talks/lorin_swint_matthews_the_dust_bunnies_that_built_our_planet/transcript?language=en
# [OK] 326 https://www.ted.com/talks/luisa_neubauer_why_you_should_be_a_climate_activist/transcript?language=en
# [OK] 327 https://www.ted.com/talks/howard_taylor_a_global_initiative_to_end_violence_against_children/transcript?language=en
# [OK] 328 https://www.ted.com/talks/andrew_marantz_inside_the_bizarre_world_of_internet_trolls_and_propagandists/transcript?language=en
# [OK] 329 https://www.ted.com/talks/anthony_veneziale_stumbling_towards_intimacy_an_improvised_ted_talk/transcript?language=en
# [OK] 330 https://www.ted.com/talks/emily_f_rothman_how_porn_changes_the_way_teens_think_about_sex/transcript?language=en
# [OK] 331 https://www.ted.com/talks/iseult_gillespie_the_secret_student_resistance_to_hitler/transcript?language=en
# [OK] 332 https://www.ted.com/talks/jochen_wegner_what_happened_when_we_paired_up_thousands_of_strangers_to_talk_politics/transcript?language=en
# [OK] 333 https://www.ted.com/talks/haaziq_kazi_a_13_year_old_s_plan_for_removing_plastic_from_the_oceans/transcript?language=en
# [OK] 334 https://www.ted.com/talks/asmeret_asefaw_berhe_a_climate_change_solution_that_s_right_under_our_feet/transcript?language=en
# [OK] 335 https://www.ted.com/talks/yeonmi_park_what_i_learned_about_freedom_after_escaping_north_korea/transcript?language=en
# [OK] 336 https://www.ted.com/talks/lee_thomas_how_i_help_people_understand_vitiligo/transcript?language=en
# [OK] 337 https://www.ted.com/talks/anne_f_broadbridge_the_rise_and_fall_of_the_mongol_empire/transcript?language=en
# [OK] 338 https://www.ted.com/talks/dessa_can_we_choose_to_fall_out_of_love_feb_2019/transcript?language=en
# [OK] 339 https://www.ted.com/talks/kelly_wanser_emergency_medicine_for_our_climate_fever/transcript?language=en
# [OK] 340 https://www.ted.com/talks/iseult_gillespie_the_myth_of_jason_and_the_argonauts/transcript?language=en
# [OK] 341 https://www.ted.com/talks/britt_wray_how_climate_change_affects_your_mental_health/transcript?language=en
# [OK] 342 https://www.ted.com/talks/luka_seamus_wright_the_mysterious_origins_of_life_on_earth/transcript?language=en
# [OK] 343 https://www.ted.com/talks/kishore_mahbubani_how_the_west_can_adapt_to_a_rising_asia/transcript?language=en
# [OK] 344 https://www.ted.com/talks/alex_gendler_a_day_in_the_life_of_a_cossack_warrior/transcript?language=en
# [OK] 345 https://www.ted.com/talks/pico_iyer_what_ping_pong_taught_me_about_life/transcript?language=en
# [OK] 346 https://www.ted.com/talks/bina_venkataraman_the_power_to_think_ahead_in_a_reckless_age/transcript?language=en
# [OK] 347 https://www.ted.com/talks/eddie_jaku_a_holocaust_survivor_s_blueprint_for_happiness/transcript?language=en
# [OK] 348 https://www.ted.com/talks/jon_lowenstein_family_hope_and_resilience_on_the_migrant_trail/transcript?language=en
# [OK] 349 https://www.ted.com/talks/iseult_gillespie_why_should_you_read_kafka_on_the_shore/transcript?language=en
# [OK] 350 https://www.ted.com/talks/joseph_gordon_levitt_how_craving_attention_makes_you_less_creative/transcript?language=en
# [OK] 351 https://www.ted.com/talks/anita_collins_the_benefits_of_music_education/transcript?language=en
# [OK] 352 https://www.ted.com/talks/sergio_feferovich_la_musica_de_las_ideas/transcript?language=en
# [OK] 353 https://www.ted.com/talks/indre_viskontas_how_music_makes_me_a_better_neuroscientist/transcript?language=en
# [OK] 354 https://www.ted.com/talks/sara_valencia_botto_when_do_kids_start_to_care_about_other_people_s_opinions/transcript?language=en
# [OK] 355 https://www.ted.com/talks/daniel_finkel_can_you_solve_the_multiverse_rescue_mission_riddle/transcript?language=en
# [OK] 356 https://www.ted.com/talks/chiara_decaroli_the_high_stakes_race_to_make_quantum_computers_work/transcript?language=en
# [OK] 357 https://www.ted.com/talks/ben_longdon_how_do_viruses_jump_from_animals_to_humans/transcript?language=en
# [OK] 358 https://www.ted.com/talks/shrabani_basu_from_pacifist_to_spy_wwii_s_surprising_secret_agent/transcript?language=en
# [OK] 359 https://www.ted.com/talks/judy_cebra_thomas_how_turtle_shells_evolved_twice/transcript?language=en
# [OK] 360 https://www.ted.com/talks/soraya_field_fiorio_the_murder_of_ancient_alexandria_s_greatest_scholar/transcript?language=en
# [OK] 361 https://www.ted.com/talks/marc_bamuthi_joseph_you_have_the_rite/transcript?language=en
# [OK] 362 https://www.ted.com/talks/margaret_heffernan_the_human_skills_we_need_in_an_unpredictable_world/transcript?language=en
# [OK] 363 https://www.ted.com/talks/victor_vescovo_what_s_at_the_bottom_of_the_ocean_and_how_we_re_getting_there/transcript?language=en
# [OK] 364 https://www.ted.com/talks/nanfu_wang_what_it_was_like_to_grow_up_under_china_s_one_child_policy/transcript?language=en
# [OK] 365 https://www.ted.com/talks/ethan_mann_how_sharks_could_inspire_a_new_generation_of_medical_devices/transcript?language=en
# [OK] 366 https://www.ted.com/talks/ocean_ramsey_why_the_world_needs_sharks/transcript?language=en
# [OK] 367 https://www.ted.com/talks/ivonne_roman_how_policewomen_make_communities_safer/transcript?language=en
# [OK] 368 https://www.ted.com/talks/nicola_sturgeon_why_governments_should_prioritize_well_being/transcript?language=en
# [OK] 369 https://www.ted.com/talks/george_monbiot_the_new_political_story_that_could_change_everything/transcript?language=en
# [OK] 370 https://www.ted.com/talks/bill_schutt_a_brief_history_of_cannibalism/transcript?language=en
# [OK] 371 https://www.ted.com/talks/tshering_tobgay_an_urgent_call_to_protect_the_world_s_third_pole/transcript?language=en
# [OK] 372 https://www.ted.com/talks/albert_laszlo_barabasi_the_real_relationship_between_your_age_and_your_chance_of_success/transcript?language=en
# [OK] 373 https://www.ted.com/talks/ilan_stavans_romance_and_revolution_the_poetry_of_pablo_neruda/transcript?language=en
# [OK] 374 https://www.ted.com/talks/hajer_sharief_how_to_use_family_dinner_to_teach_politics/transcript?language=en
# [OK] 375 https://www.ted.com/talks/rahul_mehrotra_the_architectural_wonder_of_impermanent_cities/transcript?language=en
# [OK] 376 https://www.ted.com/talks/anthony_mccarten_a_not_so_scientific_experiment_on_laughter/transcript?language=en
# [OK] 377 https://www.ted.com/talks/douglas_thomas_how_a_typeface_helped_launch_apollo/transcript?language=en
# [OK] 378 https://www.ted.com/talks/ramon_glazov_ancient_rome_s_most_notorious_doctor/transcript?language=en
# [OK] 379 https://www.ted.com/talks/elizabeth_howell_how_we_can_improve_maternal_healthcare_before_during_and_after_pregnancy/transcript?language=en
# [OK] 380 https://www.ted.com/talks/claudia_miner_a_new_way_to_get_every_child_ready_for_kindergarten/transcript?language=en
# [OK] 381 https://www.ted.com/talks/melanie_nezer_the_fundamental_right_to_seek_asylum/transcript?language=en
# [OK] 382 https://www.ted.com/talks/daniel_finkel_can_you_solve_the_dark_matter_fuel_riddle/transcript?language=en
# [OK] 383 https://www.ted.com/talks/derren_brown_mentalism_mind_reading_and_the_art_of_getting_inside_your_head/transcript?language=en
# [OK] 384 https://www.ted.com/talks/ilan_stavans_infinity_according_to_jorge_luis_borges/transcript?language=en
# [OK] 385 https://www.ted.com/talks/ella_al_shamahi_the_fascinating_and_dangerous_places_scientists_aren_t_exploring/transcript?language=en
# [OK] 386 https://www.ted.com/talks/sharmeen_obaid_chinoy_how_film_transforms_the_way_we_see_the_world/transcript?language=en
# [OK] 387 https://www.ted.com/talks/amy_padnani_how_we_re_honoring_people_overlooked_by_history/transcript?language=en
# [OK] 388 https://www.ted.com/talks/jamie_paik_origami_robots_that_reshape_and_transform_themselves/transcript?language=en
# [OK] 389 https://www.ted.com/talks/emma_bryce_what_is_hpv_and_how_can_you_protect_yourself_from_it/transcript?language=en
# [OK] 390 https://www.ted.com/talks/rick_doblin_the_future_of_psychedelic_assisted_psychotherapy/transcript?language=en
# ...
# [OK] 3850 https://www.ted.com/talks/thomas_barnett_let_s_rethink_america_s_military_strategy/transcript?language=en
# [OK] 3851 https://www.ted.com/talks/david_rockwell_a_memorial_at_ground_zero/transcript?language=en
# [OK] 3852 https://www.ted.com/talks/robert_thurman_we_can_be_buddhas/transcript?language=en
# [OK] 3853 https://www.ted.com/talks/anand_agarawala_rethink_the_desktop_with_bumptop/transcript?language=en
# [OK] 3854 https://www.ted.com/talks/ngozi_okonjo_iweala_want_to_help_africa_do_business_here/transcript?language=en
# [OK] 3855 https://www.ted.com/talks/john_doerr_salvation_and_profit_in_greentech/transcript?language=en
# [OK] 3856 https://www.ted.com/talks/blaise_aguera_y_arcas_how_photosynth_can_connect_the_world_s_images/transcript?language=en
# [OK] 3857 https://www.ted.com/talks/tierney_thys_swim_with_the_giant_sunfish/transcript?language=en
# [OK] 3858 https://www.ted.com/talks/jeff_hawkins_how_brain_science_will_change_computing/transcript?language=en
# [OK] 3859 https://www.ted.com/talks/stewart_brand_what_squatter_cities_can_teach_us/transcript?language=en
# [OK] 3860 https://www.ted.com/talks/david_kelley_human_centered_design/transcript?language=en
# [OK] 3861 https://www.ted.com/talks/james_howard_kunstler_the_ghastly_tragedy_of_the_suburbs/transcript?language=en
# [OK] 3862 https://www.ted.com/talks/stew_black_men_ski/transcript?language=en
# [OK] 3863 https://www.ted.com/talks/sergey_brin_larry_page_the_genesis_of_google/transcript?language=en
# [OK] 3864 https://www.ted.com/talks/natalie_macmaster_cape_breton_fiddling_in_reel_time/transcript?language=en
# [OK] 3865 https://www.ted.com/talks/chris_anderson_technology_s_long_tail/transcript?language=en
# [OK] 3866 https://www.ted.com/talks/rachelle_garniez_la_vie_en_rose/transcript?language=en
# [OK] 3867 https://www.ted.com/talks/tom_rielly_a_comic_sendup_of_ted2006/transcript?language=en
# [OK] 3868 https://www.ted.com/talks/richard_dawkins_militant_atheism/transcript?language=en
# [OK] 3869 https://www.ted.com/talks/tom_honey_why_would_god_create_a_tsunami/transcript?language=en
# [OK] 3870 https://www.ted.com/talks/eddi_reader_what_you_ve_got/transcript?language=en
# [OK] 3871 https://www.ted.com/talks/eddi_reader_kiteflyer_s_hill/transcript?language=en
# [OK] 3872 https://www.ted.com/talks/rives_a_mockingbird_remix_of_ted2006/transcript?language=en
# [OK] 3873 https://www.ted.com/talks/jeff_bezos_the_electricity_metaphor_for_the_web_s_future/transcript?language=en
# [OK] 3874 https://www.ted.com/talks/william_mcdonough_cradle_to_cradle_design/transcript?language=en
# [OK] 3875 https://www.ted.com/talks/evelyn_glennie_how_to_truly_listen/transcript?language=en
# [OK] 3876 https://www.ted.com/talks/dan_dennett_the_illusion_of_consciousness/transcript?language=en
# [OK] 3877 https://www.ted.com/talks/caroline_lavelle_casting_a_spell_on_the_cello/transcript?language=en
# [OK] 3878 https://www.ted.com/talks/jill_sobule_global_warming_s_theme_song_manhattan_in_january/transcript?language=en
# [OK] 3879 https://www.ted.com/talks/craig_venter_sampling_the_ocean_s_dna/transcript?language=en
# [OK] 3880 https://www.ted.com/talks/nora_york_singing_what_i_want/transcript?language=en
# [OK] 3881 https://www.ted.com/talks/alex_steffen_the_route_to_a_sustainable_future/transcript?language=en
# [OK] 3882 https://www.ted.com/talks/jane_goodall_what_separates_us_from_chimpanzees/transcript?language=en
# [OK] 3883 https://www.ted.com/talks/seth_godin_how_to_get_your_ideas_to_spread/transcript?language=en
# [OK] 3884 https://www.ted.com/talks/vik_muniz_art_with_wire_sugar_chocolate_and_string/transcript?language=en
# [OK] 3885 https://www.ted.com/talks/thom_mayne_how_architecture_can_connect_us/transcript?language=en
# [OK] 3886 https://www.ted.com/talks/susan_savage_rumbaugh_the_gentle_genius_of_bonobos/transcript?language=en
# [OK] 3887 https://www.ted.com/talks/frans_lanting_the_story_of_life_in_photographs/transcript?language=en
# [OK] 3888 https://www.ted.com/talks/stefan_sagmeister_happiness_by_design/transcript?language=en
# [OK] 3889 https://www.ted.com/talks/golan_levin_software_as_art/transcript?language=en
# [OK] 3890 https://www.ted.com/talks/chris_bangle_great_cars_are_great_art/transcript?language=en
# [OK] 3891 https://www.ted.com/talks/sheila_patek_the_shrimp_with_a_kick/transcript?language=en
# [EXCEPTION] 'NoneType' object has no attribute 'group' https://www.ted.com/talks/james_watson_how_we_discovered_dna/transcript?language=en
# [OK] 3892 https://www.ted.com/talks/juan_enriquez_the_life_code_that_will_reshape_the_future/transcript?language=en
# [OK] 3893 https://www.ted.com/talks/nick_bostrom_a_philosophical_quest_for_our_biggest_problems/transcript?language=en
# [OK] 3894 https://www.ted.com/talks/al_seckel_visual_illusions_that_show_how_we_mis_think/transcript?language=en
# [OK] 3895 https://www.ted.com/talks/dean_kamen_to_invent_is_to_give/transcript?language=en
# [OK] 3896 https://www.ted.com/talks/janine_benyus_biomimicry_s_surprising_lessons_from_nature_s_engineers/transcript?language=en
# [OK] 3897 https://www.ted.com/talks/paul_bennett_design_is_in_the_details/transcript?language=en
# [OK] 3898 https://www.ted.com/talks/james_nachtwey_my_wish_let_my_photographs_bear_witness/transcript?language=en
# [OK] 3899 https://www.ted.com/talks/bill_clinton_my_wish_rebuilding_rwanda/transcript?language=en
# [OK] 3900 https://www.ted.com/talks/e_o_wilson_my_wish_build_the_encyclopedia_of_life/transcript?language=en
# [OK] 3901 https://www.ted.com/talks/carl_honore_in_praise_of_slowness/transcript?language=en
# [OK] 3902 https://www.ted.com/talks/neil_gershenfeld_unleash_your_creativity_in_a_fab_lab/transcript?language=en
# [OK] 3903 https://www.ted.com/talks/saul_griffith_everyday_inventions/transcript?language=en
# [OK] 3904 https://www.ted.com/talks/anna_deavere_smith_four_american_characters/transcript?language=en
# [OK] 3905 https://www.ted.com/talks/steven_johnson_how_the_ghost_map_helped_end_a_killer_disease/transcript?language=en
# [OK] 3906 https://www.ted.com/talks/charles_leadbeater_the_era_of_open_innovation/transcript?language=en
# [OK] 3907 https://www.ted.com/talks/robert_wright_progress_is_not_a_zero_sum_game/transcript?language=en
# [OK] 3908 https://www.ted.com/talks/martin_rees_is_this_our_final_century/transcript?language=en
# [OK] 3909 https://www.ted.com/talks/phil_borges_photos_of_endangered_cultures/transcript?language=en
# [OK] 3910 https://www.ted.com/talks/wade_davis_dreams_from_endangered_cultures/transcript?language=en
# [OK] 3911 https://www.ted.com/talks/bjorn_lomborg_global_priorities_bigger_than_climate_change/transcript?language=en
# [OK] 3912 https://www.ted.com/talks/robert_neuwirth_the_hidden_world_of_shadow_cities/transcript?language=en
# [OK] 3913 https://www.ted.com/talks/rives_if_i_controlled_the_internet/transcript?language=en
# [OK] 3914 https://www.ted.com/talks/richard_st_john_8_secrets_of_success/transcript?language=en
# [OK] 3915 https://www.ted.com/talks/dean_ornish_the_killer_american_diet_that_s_sweeping_the_planet/transcript?language=en
# [OK] 3916 https://www.ted.com/talks/peter_gabriel_fight_injustice_with_raw_video/transcript?language=en
# [OK] 3917 https://www.ted.com/talks/ray_kurzweil_the_accelerating_power_of_technology/transcript?language=en
# [OK] 3918 https://www.ted.com/talks/kevin_kelly_how_technology_evolves/transcript?language=en
# [OK] 3919 https://www.ted.com/talks/michael_shermer_why_people_believe_weird_things/transcript?language=en
# [OK] 3920 https://www.ted.com/talks/peter_donnelly_how_juries_are_fooled_by_statistics/transcript?language=en
# [OK] 3921 https://www.ted.com/talks/bono_my_wish_three_actions_for_africa/transcript?language=en
# [OK] 3922 https://www.ted.com/talks/edward_burtynsky_my_wish_manufactured_landscapes_and_green_education/transcript?language=en
# [OK] 3923 https://www.ted.com/talks/robert_fischell_my_wish_three_unusual_medical_inventions/transcript?language=en
# [OK] 3924 https://www.ted.com/talks/ben_saunders_why_did_i_ski_to_the_north_pole/transcript?language=en
# [OK] 3925 https://www.ted.com/talks/burt_rutan_the_real_future_of_space_exploration/transcript?language=en
# [OK] 3926 https://www.ted.com/talks/ashraf_ghani_how_to_rebuild_a_broken_state/transcript?language=en
# [OK] 3927 https://www.ted.com/talks/sasa_vucinic_why_we_should_invest_in_a_free_press/transcript?language=en
# [OK] 3928 https://www.ted.com/talks/iqbal_quadir_how_mobile_phones_can_fight_poverty/transcript?language=en
# [OK] 3929 https://www.ted.com/talks/jacqueline_novogratz_invest_in_africa_s_own_solutions/transcript?language=en
# [OK] 3930 https://www.ted.com/talks/eva_vertes_meet_the_future_of_cancer_research/transcript?language=en
# [OK] 3931 https://www.ted.com/talks/aubrey_de_grey_a_roadmap_to_end_aging/transcript?language=en
# [OK] 3932 https://www.ted.com/talks/dan_gilbert_the_surprising_science_of_happiness/transcript?language=en
# [EXCEPTION] 'NoneType' object has no attribute 'group' https://www.ted.com/talks/barry_schwartz_the_paradox_of_choice/transcript?language=en
# [OK] 3933 https://www.ted.com/talks/malcolm_gladwell_choice_happiness_and_spaghetti_sauce/transcript?language=en
# [OK] 3934 https://www.ted.com/talks/steven_levitt_the_freakonomics_of_crack_dealing/transcript?language=en
# [OK] 3935 https://www.ted.com/talks/david_deutsch_chemical_scum_that_dream_of_distant_quasars/transcript?language=en
# [OK] 3936 https://www.ted.com/talks/richard_dawkins_why_the_universe_seems_so_strange/transcript?language=en
# [OK] 3937 https://www.ted.com/talks/helen_fisher_why_we_love_why_we_cheat/transcript?language=en
# [OK] 3938 https://www.ted.com/talks/eve_ensler_happiness_in_body_and_soul/transcript?language=en
# [OK] 3939 https://www.ted.com/talks/mena_trott_meet_the_founder_of_the_blog_revolution/transcript?language=en
# [OK] 3940 https://www.ted.com/talks/ze_frank_nerdcore_comedy/transcript?language=en
# [OK] 3941 https://www.ted.com/talks/jimmy_wales_the_birth_of_wikipedia/transcript?language=en
# [OK] 3942 https://www.ted.com/talks/richard_baraniuk_the_birth_of_the_open_source_learning_revolution/transcript?language=en
# [OK] 3943 https://www.ted.com/talks/ross_lovegrove_organic_design_inspired_by_nature/transcript?language=en
# [OK] 3944 https://www.ted.com/talks/amy_smith_simple_designs_to_save_a_life/transcript?language=en
# [OK] 3945 https://www.ted.com/talks/jennifer_lin_improvising_on_piano_aged_14/transcript?language=en
# [OK] 3946 https://www.ted.com/talks/sirena_huang_an_11_year_old_s_magical_violin/transcript?language=en
# [OK] 3947 https://www.ted.com/talks/jeff_han_the_radical_promise_of_the_multi_touch_interface/transcript?language=en
# [OK] 3948 https://www.ted.com/talks/nicholas_negroponte_one_laptop_per_child/transcript?language=en
# [OK] 3949 https://www.ted.com/talks/cameron_sinclair_my_wish_a_call_for_open_source_architecture/transcript?language=en
# [OK] 3950 https://www.ted.com/talks/jehane_noujaim_my_wish_a_global_day_of_film/transcript?language=en
# [OK] 3951 https://www.ted.com/talks/larry_brilliant_my_wish_help_me_stop_pandemics/transcript?language=en
# [OK] 3952 https://www.ted.com/talks/dan_dennett_let_s_teach_religion_all_religion_in_schools/transcript?language=en
# [OK] 3953 https://www.ted.com/talks/rick_warren_a_life_of_purpose/transcript?language=en
# [OK] 3954 https://www.ted.com/talks/julia_sweeney_letting_go_of_god/transcript?language=en
# [OK] 3955 https://www.ted.com/talks/joshua_prince_ramus_behind_the_design_of_seattle_s_library/transcript?language=en
# [OK] 3956 https://www.ted.com/talks/hans_rosling_the_best_stats_you_ve_ever_seen/transcript?language=en
# [EXCEPTION] 'NoneType' object has no attribute 'group' https://www.ted.com/talks/sir_ken_robinson_do_schools_kill_creativity/transcript?language=en
# [OK] 3957 https://www.ted.com/talks/majora_carter_greening_the_ghetto/transcript?language=en
# [OK] 3958 https://www.ted.com/talks/david_pogue_simplicity_sells/transcript?language=en
# [OK] 3959 https://www.ted.com/talks/al_gore_averting_the_climate_crisis/transcript?language=en
#
# Ted.com scraping results:
#
# 	• Successful: 3960
#
# 	• Failed: 38
#
# Failed to scrape:
# ['https://www.ted.com/talks/arturs_miksons_the_benefits_of_expressing_your_emotions_constructively/transcript?language=en', 'https://www.ted.com/talks/a_j_jacobs_the_evolution_of_the_coffee_cup_lid/transcript?language=en', 'https://www.ted.com/talks/kimberly_noble_how_does_income_affect_childhood_brain_development/transcript?language=en', 'https://www.ted.com/talks/iseult_gillespie_the_wicked_wit_of_jane_austen/transcript?language=en', 'https://www.ted.com/talks/iseult_gillespie_why_should_you_read_shakespeare_s_the_tempest/transcript?language=en', 'https://www.ted.com/talks/patty_mccord_8_lessons_on_building_a_company_people_enjoy_working_for/transcript?language=en', 'https://www.ted.com/talks/thea_holcomb_how_peer_educators_can_transform_sex_education/transcript?language=en', 'https://www.ted.com/talks/michael_c_bush_this_is_what_makes_employees_happy_at_work/transcript?language=en', 'https://www.ted.com/talks/kelly_richmond_pope_how_whistle_blowers_shape_history/transcript?language=en', 'https://www.ted.com/talks/dan_knights_how_we_study_the_microbes_living_in_your_gut/transcript?language=en', 'https://www.ted.com/talks/emily_nagoski_the_keys_to_a_happier_healthier_sex_life/transcript?language=en', 'https://www.ted.com/talks/mel_robbins_how_to_stop_screwing_yourself_over/transcript?language=en', 'https://www.ted.com/talks/leah_chase_and_pat_mitchell_an_interview_with_the_queen_of_creole_cuisine/transcript?language=en', 'https://www.ted.com/talks/amel_karboul_the_global_learning_crisis_and_what_to_do_about_it/transcript?language=en', 'https://www.ted.com/talks/ann_morgan_my_year_reading_a_book_from_every_country_in_the_world/transcript?language=en', 'https://www.ted.com/talks/alison_killing_there_s_a_better_way_to_die_and_architecture_can_help/transcript?language=en', 'https://www.ted.com/talks/hans_and_ola_rosling_how_not_to_be_ignorant_about_the_world/transcript?language=en', 'https://www.ted.com/talks/george_zaidan_why_is_ketchup_so_hard_to_pour/transcript?language=en', 'https://www.ted.com/talks/arthur_benjamin_the_magic_of_fibonacci_numbers/transcript?language=en', 'https://www.ted.com/talks/marjee_chmiel_and_trevor_owens_is_there_a_center_of_the_universe/transcript?language=en', 'https://www.ted.com/talks/allan_savory_how_to_fight_desertification_and_reverse_climate_change/transcript?language=en', 'https://www.ted.com/talks/caitria_morgan_o_neill_how_to_step_up_in_the_face_of_disaster/transcript?language=en', 'https://www.ted.com/talks/philippe_petit_the_journey_across_the_high_wire/transcript?language=en', 'https://www.ted.com/talks/eduardo_paes_the_4_commandments_of_cities/transcript?language=en', 'https://www.ted.com/talks/robin_ince_science_versus_wonder/transcript?language=en', 'https://www.ted.com/talks/honor_harger_a_history_of_the_universe_in_sound/transcript?language=en', 'https://www.ted.com/talks/susan_shaw_the_oil_spill_s_toxic_trade_off/transcript?language=en', 'https://www.ted.com/talks/edith_widder_glowing_life_in_an_underwater_world/transcript?language=en', 'https://www.ted.com/talks/ed_ulbrich_how_benjamin_button_got_his_face/transcript?language=en', 'https://www.ted.com/talks/samantha_power_a_complicated_hero_in_the_war_on_dictatorship/transcript?language=en', 'https://www.ted.com/talks/rives_a_story_of_mixed_emoticons/transcript?language=en', 'https://www.ted.com/talks/lennart_green_close_up_card_magic_with_a_twist/transcript?language=en', 'https://www.ted.com/talks/seyi_oyesola_a_hospital_tour_in_nigeria/transcript?language=en', 'https://www.ted.com/talks/johnny_lee_free_or_cheap_wii_remote_hacks/transcript?language=en', 'https://www.ted.com/talks/robin_chase_the_idea_behind_zipcar_and_what_comes_next/transcript?language=en', 'https://www.ted.com/talks/james_watson_how_we_discovered_dna/transcript?language=en', 'https://www.ted.com/talks/barry_schwartz_the_paradox_of_choice/transcript?language=en', 'https://www.ted.com/talks/sir_ken_robinson_do_schools_kill_creativity/transcript?language=en']

# %%
# failed on 2020-04-29
failed = ['https://www.ted.com/talks/arturs_miksons_the_benefits_of_expressing_your_emotions_constructively/transcript?language=en', 'https://www.ted.com/talks/a_j_jacobs_the_evolution_of_the_coffee_cup_lid/transcript?language=en', 'https://www.ted.com/talks/kimberly_noble_how_does_income_affect_childhood_brain_development/transcript?language=en', 'https://www.ted.com/talks/iseult_gillespie_the_wicked_wit_of_jane_austen/transcript?language=en', 'https://www.ted.com/talks/iseult_gillespie_why_should_you_read_shakespeare_s_the_tempest/transcript?language=en', 'https://www.ted.com/talks/patty_mccord_8_lessons_on_building_a_company_people_enjoy_working_for/transcript?language=en', 'https://www.ted.com/talks/thea_holcomb_how_peer_educators_can_transform_sex_education/transcript?language=en', 'https://www.ted.com/talks/michael_c_bush_this_is_what_makes_employees_happy_at_work/transcript?language=en', 'https://www.ted.com/talks/kelly_richmond_pope_how_whistle_blowers_shape_history/transcript?language=en', 'https://www.ted.com/talks/dan_knights_how_we_study_the_microbes_living_in_your_gut/transcript?language=en', 'https://www.ted.com/talks/emily_nagoski_the_keys_to_a_happier_healthier_sex_life/transcript?language=en', 'https://www.ted.com/talks/mel_robbins_how_to_stop_screwing_yourself_over/transcript?language=en', 'https://www.ted.com/talks/leah_chase_and_pat_mitchell_an_interview_with_the_queen_of_creole_cuisine/transcript?language=en', 'https://www.ted.com/talks/amel_karboul_the_global_learning_crisis_and_what_to_do_about_it/transcript?language=en', 'https://www.ted.com/talks/ann_morgan_my_year_reading_a_book_from_every_country_in_the_world/transcript?language=en', 'https://www.ted.com/talks/alison_killing_there_s_a_better_way_to_die_and_architecture_can_help/transcript?language=en', 'https://www.ted.com/talks/hans_and_ola_rosling_how_not_to_be_ignorant_about_the_world/transcript?language=en', 'https://www.ted.com/talks/george_zaidan_why_is_ketchup_so_hard_to_pour/transcript?language=en', 'https://www.ted.com/talks/arthur_benjamin_the_magic_of_fibonacci_numbers/transcript?language=en', 'https://www.ted.com/talks/marjee_chmiel_and_trevor_owens_is_there_a_center_of_the_universe/transcript?language=en', 'https://www.ted.com/talks/allan_savory_how_to_fight_desertification_and_reverse_climate_change/transcript?language=en', 'https://www.ted.com/talks/caitria_morgan_o_neill_how_to_step_up_in_the_face_of_disaster/transcript?language=en', 'https://www.ted.com/talks/philippe_petit_the_journey_across_the_high_wire/transcript?language=en', 'https://www.ted.com/talks/eduardo_paes_the_4_commandments_of_cities/transcript?language=en', 'https://www.ted.com/talks/robin_ince_science_versus_wonder/transcript?language=en', 'https://www.ted.com/talks/honor_harger_a_history_of_the_universe_in_sound/transcript?language=en', 'https://www.ted.com/talks/susan_shaw_the_oil_spill_s_toxic_trade_off/transcript?language=en', 'https://www.ted.com/talks/edith_widder_glowing_life_in_an_underwater_world/transcript?language=en', 'https://www.ted.com/talks/ed_ulbrich_how_benjamin_button_got_his_face/transcript?language=en', 'https://www.ted.com/talks/samantha_power_a_complicated_hero_in_the_war_on_dictatorship/transcript?language=en', 'https://www.ted.com/talks/rives_a_story_of_mixed_emoticons/transcript?language=en', 'https://www.ted.com/talks/lennart_green_close_up_card_magic_with_a_twist/transcript?language=en', 'https://www.ted.com/talks/seyi_oyesola_a_hospital_tour_in_nigeria/transcript?language=en', 'https://www.ted.com/talks/johnny_lee_free_or_cheap_wii_remote_hacks/transcript?language=en', 'https://www.ted.com/talks/robin_chase_the_idea_behind_zipcar_and_what_comes_next/transcript?language=en', 'https://www.ted.com/talks/james_watson_how_we_discovered_dna/transcript?language=en', 'https://www.ted.com/talks/barry_schwartz_the_paradox_of_choice/transcript?language=en', 'https://www.ted.com/talks/sir_ken_robinson_do_schools_kill_creativity/transcript?language=en']

# %%
# spanish
scraper_es = TEDscraper()
ted_dict = scraper_es.get_data()

# %%
df = scraper_en.to_dataframe(ted_dict)
df.shape
# Out:
# (3960, 19)

# %% [markdown]
# # Testing

# %%
soup = 'https://www.ted.com/talks/a_j_jacobs_the_evolution_of_the_coffee_cup_lid/transcript?language=en'

# %%
scraper = TEDscraper(urls=['https://www.ted.com/talks/a_j_jacobs_the_evolution_of_the_coffee_cup_lid/transcript?language=en'])

# %% [markdown]
# ### Support Code

# %%
def make_soup(url):
    """Returns soup object from a URL."""
    # generate random user-agent
    user_agent = {'User-agent': UserAgent().random}
    # request page and make soup
    page = requests.get(url, headers=user_agent)
    soup = BeautifulSoup(page.content, 'lxml')
    return soup

# %%
# all features
scraper.get_talk_id(soup)
scraper.get_title(soup)
scraper.get_all_speakers(soup)
scraper.get_occupations(soup)
scraper.get_about_speakers(soup)
scraper.get_views(soup)
scraper.get_recorded_date(soup)
scraper.get_published_date(soup)
scraper.get_event(soup)
scraper.get_native_lang(soup)
scraper.get_available_lang(soup)
scraper.get_comments_count(soup)
scraper.get_duration(soup)
scraper.get_topics(soup)
scraper.get_related_talks(soup)
scraper.get_talk_url(soup)
scraper.get_description(soup)
scraper.get_transcript(soup)

scraper.get_title(soup)

# %%
# Test urls
urls = [
    'https://www.ted.com/talks/sarah_kaminsky_my_father_the_forger/',
    'https://www.ted.com/talks/jorge_drexler_poetry_music_and_identity/transcript',
    'https://www.ted.com/talks/sir_ken_robinson_do_schools_kill_creativity/',
    'https://www.ted.com/talks/paul_mceuen_and_marc_miskin_tiny_robots_with_giant_potential/transcript',
    'https://www.ted.com/talks/antara_raychaudhuri_and_iseult_gillespie_the_legend_of_annapurna_hindu_goddess_of_nourishment/',
    'https://www.ted.com/talks/diana_reiss_peter_gabriel_neil_gershenfeld_and_vint_cerf_the_interspecies_internet_an_idea_in_progress/',
]

# %%
# urls_issues
issues = [
    # should be removed
    'https://www.ted.com/talks/zohreh_davoudi_are_we_living_in_a_simulation/',
    'https://www.ted.com/talks/marcus_bullock_an_app_that_helps_incarcerated_people_stay_connected_to_their_families/transcript?language=en', # only in 'en'
    'https://www.ted.com/talks/anton_garcia_abril_how_prefab_homes_can_transform_affordable_housing/',
    
    # good ones
    'https://www.ted.com/talks/jorge_drexler_poetry_music_and_identity/transcript?language=en',
    'https://www.ted.com/talks/sarah_kaminsky_my_father_the_forger/',
]

# %%
viewed_zero = [
    'https://www.ted.com/talks/angel_chang_the_life_cycle_of_a_sneaker',
     'https://www.ted.com/talks/diego_prilusky_como_sera_el_cine_del_futuro',
     'https://www.ted.com/talks/james_logan_can_dogs_sniff_out_malaria_jan_2019',
     'https://www.ted.com/talks/renata_di_tullio_por_que_deberiamos_comer_mas_bichos',
     'https://www.ted.com/talks/alejandro_chaskielberg_como_usar_el_arte_de_la_fotografia_para_restaurar_la_memoria',
     'https://www.ted.com/talks/enric_sala_por_que_necesitamos_proteger_el_alta_mar',
     'https://www.ted.com/talks/jr_undocumented_lives_inside_out'
]

# %%
errors = [
    'https://www.ted.com/talks/marcus_bullock_an_app_that_helps_incarcerated_people_stay_connected_to_their_families/transcript?language=en',
    'https://www.ted.com/talks/marilyn_waring_the_unpaid_work_that_gdp_ignores_and_why_it_really_counts/',
    'https://www.ted.com/talks/zohreh_davoudi_are_we_living_in_a_simulation/',
    'https://www.ted.com/talks/maisie_williams_why_talent_carries_you_further_than_fame/',
    'https://www.ted.com/talks/keith_lowe_why_we_need_to_stop_obsessing_over_world_war_ii/',
    'https://www.ted.com/talks/anton_garcia_abril_how_prefab_homes_can_transform_affordable_housing/',
]
errors_sr = pd.Series(errors, name='errors_urls')

# %%
errors_sr.to_csv('../data/urls_errors.csv', index=False)

# %% [markdown]
# ## Known Issues
#
# #### Talks that weren't scraped
# * Talk is in English but has no English transcript
#     * https://www.ted.com/talks/marcus_bullock_an_app_that_helps_incarcerated_people_stay_connected_to_their_families/transcript?language=en
# * No 'recorded_date'
#     * https://www.ted.com/talks/marilyn_waring_the_unpaid_work_that_gdp_ignores_and_why_it_really_counts/
# * Speakers info is missing
#     * The name is available elsewhere, but not the occupation
#     * https://www.ted.com/talks/zohreh_davoudi_are_we_living_in_a_simulation/
#     * https://www.ted.com/talks/maisie_williams_why_talent_carries_you_further_than_fame/
#     * https://www.ted.com/talks/keith_lowe_why_we_need_to_stop_obsessing_over_world_war_ii/
#     * https://www.ted.com/talks/anton_garcia_abril_how_prefab_homes_can_transform_affordable_housing/
